# %% [markdown]
# # Face Generation
#
# In this project, you'll define and train a DCGAN on a dataset of faces. Your goal is to get a generator network to generate *new* images of faces that look as realistic as possible!
#
# The project will be broken down into a series of tasks from **loading in data to defining and training adversarial networks**. At the end of the notebook, you'll be able to visualize the results of your trained Generator to see how it performs; your generated samples should look like fairly realistic faces with small amounts of noise.
#
# ### Get the Data
#
# You'll be using the [CelebFaces Attributes Dataset (CelebA)](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) to train your adversarial networks.
#
# This dataset is more complex than the number datasets (like MNIST or SVHN) you've been working with, and so, you should prepare to define deeper networks and train them for a longer time to get good results. It is suggested that you utilize a GPU for training.
#
# ### Pre-processed Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. Some sample data is show below.
#
# <img src='assets/processed_face_data.png' width=60% />
#
# > If you are working locally, you can download this data [by clicking here](https://s3.amazonaws.com/video.udacity-data.com/topher/2018/November/5be7eb6f_processed-celeba-small/processed-celeba-small.zip)
#
# This is a zip file that you'll need to extract in the home directory of this notebook for further loading and processing. After extracting the data, you should be left with a directory of data `processed_celeba_small/`

# %%
# can comment out after executing
#!unzip processed_celeba_small.zip

# %%
data_dir = 'processed_celeba_small/'

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle as pkl
import matplotlib.pyplot as plt
import numpy as np
import problem_unittests as tests
#import helper

# %matplotlib inline

# %% [markdown]
# ## Visualize the CelebA Data
#
# The [CelebA](http://mmlab.ie.cuhk.edu.hk/projects/CelebA.html) dataset contains over 200,000 celebrity images with annotations. Since you're going to be generating faces, you won't need the annotations, you'll only need the images. Note that these are color images with [3 color channels (RGB)](https://en.wikipedia.org/wiki/Channel_(digital_image)#RGB_Images) each.
#
# ### Pre-process and Load the Data
#
# Since the project's main focus is on building the GANs, we've done *some* of the pre-processing for you. Each of the CelebA images has been cropped to remove parts of the image that don't include a face, then resized down to 64x64x3 NumPy images. This *pre-processed* dataset is a smaller subset of the very large CelebA data.
#
# > There are a few other steps that you'll need to **transform** this data and create a **DataLoader**.
#
# #### Exercise: Complete the following `get_dataloader` function, such that it satisfies these requirements:
#
# * Your images should be square, Tensor images of size `image_size x image_size` in the x and y dimension.
# * Your function should return a DataLoader that shuffles and batches these Tensor images.
#
# #### ImageFolder
#
# To create a dataset given a directory of images, it's recommended that you use PyTorch's [ImageFolder](https://pytorch.org/docs/0.4.0/torchvision/datasets.html#imagefolder) wrapper, with a root directory `processed_celeba_small/` and data transformation passed in.

# %%
# necessary imports
import torch
from torchvision import datasets
from torchvision import transforms
import os
from torch.utils.data import DataLoader

# %%
def get_dataloader(batch_size, image_size, data_dir='processed_celeba_small/'):
    """
    Batch the neural network data using DataLoader
    :param batch_size: The size of each batch; the number of images in a batch
    :param img_size: The square size of the image data (x, y)
    :param data_dir: Directory where image data is located
    :return: DataLoader with batched data
    # resize and normalize the images
   
    """
    
    # TODO: Implement function and return a dataloader
    transform = transforms.Compose([transforms.Resize(image_size), 
                                    transforms.ToTensor()])

    # get training and test directories
    image_path = './' + data_dir
    train_path = os.path.join(image_path)

    # define datasets using ImageFolder
    train_dataset = datasets.ImageFolder(train_path, transform)

    # create and return DataLoaders
    train_loader = DataLoader(dataset=train_dataset, batch_size=batch_size, shuffle=True)
    return train_loader

# %% [markdown]
# ## Create a DataLoader
#
# #### Exercise: Create a DataLoader `celeba_train_loader` with appropriate hyperparameters.
#
# Call the above function and create a dataloader to view images.
# * You can decide on any reasonable `batch_size` parameter
# * Your `image_size` **must be** `32`. Resizing the data to a smaller size will make for faster training, while still creating convincing images of faces!

# %%
# Define function hyperparameters
batch_size = 25
img_size = 32

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# Call your function and get a dataloader
celeba_train_loader = get_dataloader(batch_size, img_size)

# %% [markdown]
# Next, you can view some images! You should seen square images of somewhat-centered faces.
#
# Note: You'll need to convert the Tensor images into a NumPy type and transpose the dimensions to correctly display an image, suggested `imshow` code is below, but it may not be perfect.

# %%
# helper display function
def imshow(img):
    npimg = img.numpy()
    plt.imshow(np.transpose(npimg, (1, 2, 0)))

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# obtain one batch of training images
dataiter = iter(celeba_train_loader)
images, _ = dataiter.next() # _ for no labels

# plot the images in the batch, along with the corresponding labels
fig = plt.figure(figsize=(20, 4))
plot_size=20
for idx in np.arange(plot_size):
    ax = fig.add_subplot(2, plot_size/2, idx+1, xticks=[], yticks=[])
    imshow(images[idx])

# %% [markdown]
# #### Exercise: Pre-process your image data and scale it to a pixel range of -1 to 1
#
# You need to do a bit of pre-processing; you know that the output of a `tanh` activated generator will contain pixel values in a range from -1 to 1, and so, we need to rescale our training images to a range of -1 to 1. (Right now, they are in a range from 0-1.)

# %%
# TODO: Complete the scale function
def scale(x, feature_range=(-1, 1)):
    ''' Scale takes in an image x and returns that image, scaled
       with a feature_range of pixel values from -1 to 1. 
       This function assumes that the input x is already scaled from 0-1.'''
    # assume x is scaled to (0, 1)
    # scale to feature_range and return scaled x
    min,max = feature_range
    x = ((max-min)*x)+min
    
    return x

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
# check scaled range
# should be close to -1 to 1
img = images[0]
scaled_img = scale(img)

print('Min: ', scaled_img.min())
print('Max: ', scaled_img.max())
# Out:
# Min:  tensor(-0.9373)
# Max:  tensor(0.8510)

# %% [markdown]
# ---
# # Define the Model
#
# A GAN is comprised of two adversarial networks, a discriminator and a generator.
#
# ## Discriminator
#
# Your first task will be to define the discriminator. This is a convolutional classifier like you've built before, only without any maxpooling layers. To deal with this complex data, it's suggested you use a deep network with **normalization**. You are also allowed to create any helper functions that may be useful.
#
# #### Exercise: Complete the Discriminator class
# * The inputs to the discriminator are 32x32x3 tensor images
# * The output should be a single value that will indicate whether a given image is real or fake

# %%
import torch.nn as nn
import torch.nn.functional as F

# %%
def conv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_layer = nn.Conv2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    

    layers.append(conv_layer)

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
     
    
    return nn.Sequential(*layers)


class Discriminator(nn.Module):

    def __init__(self, conv_dim):
        """
        Initialize the Discriminator Module
        :param conv_dim: The depth of the first convolutional layer
        """
        super(Discriminator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim
        self.conv1 = conv(3,conv_dim,4,batch_norm=False)
        self.conv2 = conv(conv_dim,conv_dim*2, 4)
        self.conv3 = conv(conv_dim*2,conv_dim*4, 4)
        self.conv4 = conv(conv_dim*4,conv_dim*8, 4)
        self.fcn = nn.Linear(conv_dim*8*2*2,1)
        self.Activation = nn.LeakyReLU(0.2)
        
        
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: Discriminator logits; the output of the neural network
        """
        # define feedforward behavior
        x = self.conv1(x)
        x = self.Activation(x)
        x = self.conv2(x)
        x = self.Activation(x)
        x = self.conv3(x)
        x = self.Activation(x)
        x = self.conv4(x)
        x = self.Activation(x)
        x = x.view(-1,self.conv_dim*8*2*2)
        x = self.fcn(x)
        
        
        return x


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_discriminator(Discriminator)
# Out:
# Tests Passed

# %% [markdown]
# ## Generator
#
# The generator should upsample an input and generate a *new* image of the same size as our training data `32x32x3`. This should be mostly transpose convolutional layers with normalization applied to the outputs.
#
# #### Exercise: Complete the Generator class
# * The inputs to the generator are vectors of some length `z_size`
# * The output should be a image of shape `32x32x3`

# %%
def deconv(in_channels, out_channels, kernel_size, stride=2, padding=1, batch_norm=True):
    """Creates a transposed-convolutional layer, with optional batch normalization.
    """
    layers = []
    conv_transpose_layer = nn.ConvTranspose2d(in_channels, out_channels, 
                           kernel_size, stride, padding, bias=False)
    
    layers.append(conv_transpose_layer)

    if batch_norm:
        layers.append(nn.BatchNorm2d(out_channels))
     
    
    return nn.Sequential(*layers)




class Generator(nn.Module):
    
    def __init__(self, z_size, conv_dim):
        """
        Initialize the Generator Module
        :param z_size: The length of the input latent vector, z
        :param conv_dim: The depth of the inputs to the *last* transpose convolutional layer
        """
        super(Generator, self).__init__()

        # complete init function
        self.conv_dim = conv_dim

        self.fc = nn.Linear(z_size, conv_dim*8*2*2)
        
        self.t_conv1 = deconv(conv_dim*8, conv_dim*4, 4)
        self.t_conv2 = deconv(conv_dim*4, conv_dim*2, 4)
        self.t_conv3 = deconv(conv_dim*2, conv_dim, 4)
        self.t_conv4 = deconv(conv_dim, 3, 4, batch_norm=False)
        

        
        

    def forward(self, x):
        """
        Forward propagation of the neural network
        :param x: The input to the neural network     
        :return: A 32x32x3 Tensor image as output
        """
        # define feedforward behavior
        out = self.fc(x)
        out = out.view(-1, self.conv_dim*8, 2, 2)
        
        out = F.relu(self.t_conv1(out))
        out = F.relu(self.t_conv2(out))
        out = F.relu(self.t_conv3(out))
        
        # last layer: tanh activation instead of relu
        out = self.t_conv4(out)
        out = F.tanh(out)
        
        return out

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_generator(Generator)
# Out:
# Tests Passed

# %% [markdown]
# ## Initialize the weights of your networks
#
# To help your models converge, you should initialize the weights of the convolutional and linear layers in your model. From reading the [original DCGAN paper](https://arxiv.org/pdf/1511.06434.pdf), they say:
# > All weights were initialized from a zero-centered Normal distribution with standard deviation 0.02.
#
# So, your next task will be to define a weight initialization function that does just this!
#
# You can refer back to the lesson on weight initialization or even consult existing model code, such as that from [the `networks.py` file in CycleGAN Github repository](https://github.com/junyanz/pytorch-CycleGAN-and-pix2pix/blob/master/models/networks.py) to help you complete this function.
#
# #### Exercise: Complete the weight initialization function
#
# * This should initialize only **convolutional** and **linear** layers
# * Initialize the weights to a normal distribution, centered around 0, with a standard deviation of 0.02.
# * The bias terms, if they exist, may be left alone or set to 0.

# %%
def weights_init_normal(m):
    """
    Applies initial weights to certain layers in a model .
    The weights are taken from a normal distribution 
    with mean = 0, std dev = 0.02.
    :param m: A module or layer in a network    
    """
    # classname will be something like:
    # `Conv`, `BatchNorm2d`, `Linear`, etc.
    classname = m.__class__.__name__
    if classname.find("Conv") != -1 or classname.find('Linear') != -1:
        torch.nn.init.normal_(m.weight.data, 0.0, 0.02)
    elif classname.find("BatchNorm2d") != -1:
        torch.nn.init.normal_(m.weight.data, 1.0, 0.02)
        torch.nn.init.constant_(m.bias.data, 0.0)
    
    
    # TODO: Apply initial weights to convolutional and linear layers

# %% [markdown]
# ## Build complete network
#
# Define your models' hyperparameters and instantiate the discriminator and generator from the classes defined above. Make sure you've passed in the correct input arguments.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
def build_network(d_conv_dim, g_conv_dim, z_size):
    # define discriminator and generator
    D = Discriminator(d_conv_dim)
    G = Generator(z_size=z_size, conv_dim=g_conv_dim)

    # initialize model weights
    D.apply(weights_init_normal)
    G.apply(weights_init_normal)

    print(D)
    print()
    print(G)
    
    return D, G

# %% [markdown]
# #### Exercise: Define model hyperparameters

# %%
# Define model hyperparams
d_conv_dim = 32
g_conv_dim = 32
z_size = 100

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
D, G = build_network(d_conv_dim, g_conv_dim, z_size)
# Out:
# Discriminator(
#   (conv1): Sequential(
#     (0): Conv2d(3, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
#   (conv2): Sequential(
#     (0): Conv2d(32, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv3): Sequential(
#     (0): Conv2d(64, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (conv4): Sequential(
#     (0): Conv2d(128, 256, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (fcn): Linear(in_features=1024, out_features=1, bias=True)
#   (Activation): LeakyReLU(negative_slope=0.2)
# )
#
# Generator(
#   (fc): Linear(in_features=100, out_features=1024, bias=True)
#   (t_conv1): Sequential(
#     (0): ConvTranspose2d(256, 128, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(128, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv2): Sequential(
#     (0): ConvTranspose2d(128, 64, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(64, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv3): Sequential(
#     (0): ConvTranspose2d(64, 32, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#     (1): BatchNorm2d(32, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   )
#   (t_conv4): Sequential(
#     (0): ConvTranspose2d(32, 3, kernel_size=(4, 4), stride=(2, 2), padding=(1, 1), bias=False)
#   )
# )

# %% [markdown]
# ### Training on GPU
#
# Check if you can train on GPU. Here, we'll set this as a boolean variable `train_on_gpu`. Later, you'll be responsible for making sure that
# >* Models,
# * Model inputs, and
# * Loss function arguments
#
# Are moved to GPU, where appropriate.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import torch

# Check for a GPU
train_on_gpu = torch.cuda.is_available()
if not train_on_gpu:
    print('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Training on GPU!')
# Out:
# Training on GPU!

# %% [markdown]
# ---
# ## Discriminator and Generator Losses
#
# Now we need to calculate the losses for both types of adversarial networks.
#
# ### Discriminator Losses
#
# > * For the discriminator, the total loss is the sum of the losses for real and fake images, `d_loss = d_real_loss + d_fake_loss`.
# * Remember that we want the discriminator to output 1 for real images and 0 for fake images, so we need to set up the losses to reflect that.
#
#
# ### Generator Loss
#
# The generator loss will look similar only with flipped labels. The generator's goal is to get the discriminator to *think* its generated images are *real*.
#
# #### Exercise: Complete real and fake loss functions
#
# **You may choose to use either cross entropy or a least squares error loss to complete the following `real_loss` and `fake_loss` functions.**

# %%
def real_loss(D_out, smooth=False):
    '''Calculates how close discriminator outputs are to being real.
       param, D_out: discriminator logits
       return: real loss'''
    batch_size = D_out.size(0)
    # label smoothing
    if smooth:
        # smooth, real labels = 0.9
        labels = torch.ones(batch_size)*0.9
    else:
        labels = torch.ones(batch_size) # real labels = 1
    # move labels to GPU if available     
    if train_on_gpu:
        labels = labels.cuda()
    # binary cross entropy with logits loss
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

def fake_loss(D_out):
    '''Calculates how close discriminator outputs are to being fake.
       param, D_out: discriminator logits
       return: fake loss'''
    batch_size = D_out.size(0)
    labels = torch.zeros(batch_size) # fake labels = 0
    if train_on_gpu:
        labels = labels.cuda()
    criterion = nn.BCEWithLogitsLoss()
    # calculate loss
    loss = criterion(D_out.squeeze(), labels)
    return loss

# %% [markdown]
# ## Optimizers
#
# #### Exercise: Define optimizers for your Discriminator (D) and Generator (G)
#
# Define optimizers for your models with appropriate hyperparameters.

# %%
import torch.optim as optim
lr = 0.002
beta1 = 0.5
beta2 = 0.999

# Create optimizers for the discriminator D and generator G
d_optimizer = optim.Adam(D.parameters(), lr, [beta1, beta2])
g_optimizer = optim.Adam(G.parameters(), lr, [beta1, beta2])

# %% [markdown]
# ---
# ## Training
#
# Training will involve alternating between training the discriminator and the generator. You'll use your functions `real_loss` and `fake_loss` to help you calculate the discriminator losses.
#
# * You should train the discriminator by alternating on real and fake images
# * Then the generator, which tries to trick the discriminator and should have an opposing loss function
#
#
# #### Saving Samples
#
# You've been given some code to print out some loss statistics and save some generated "fake" samples.

# %% [markdown]
# #### Exercise: Complete the training function
#
# Keep in mind that, if you've moved your models to GPU, you'll also have to move any model inputs to GPU.

# %%
def train(D, G, n_epochs, print_every=50):
    '''Trains adversarial networks for some number of epochs
       param, D: the discriminator network
       param, G: the generator network
       param, n_epochs: number of epochs to train for
       param, print_every: when to print and record the models' losses
       return: D and G losses'''
    
    # move models to GPU
    if train_on_gpu:
        D.cuda()
        G.cuda()

    # keep track of loss and generated, "fake" samples
    samples = []
    losses = []

    # Get some fixed data for sampling. These are images that are held
    # constant throughout training, and allow us to inspect the model's performance
    sample_size=16
    fixed_z = np.random.uniform(-1, 1, size=(sample_size, z_size))
    fixed_z = torch.from_numpy(fixed_z).float()
    # move z to GPU if available
    if train_on_gpu:
        fixed_z = fixed_z.cuda()

    # epoch training loop
    for epoch in range(n_epochs):

        # batch training loop
        for batch_i, (real_images, _) in enumerate(celeba_train_loader):

            batch_size = real_images.size(0)
            real_images = scale(real_images)
            # ===============================================
            #         YOUR CODE HERE: TRAIN THE NETWORKS
            # ===============================================
            
            # 1. Train the discriminator on real and fake images
            d_optimizer.zero_grad()
            if train_on_gpu:
                real_images = real_images.cuda()
                
            D_real = D(real_images)
            d_real_loss = real_loss(D_real)
            
            z = np.random.uniform(-1, 1, size = (batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            
            fake_images = G(z)
            D_fake = D(fake_images)
            d_fake_loss = fake_loss(D_fake)
            
            d_loss = d_real_loss + d_fake_loss
            d_loss.backward()
            d_optimizer.step()

            # 2. Train the generator with an adversarial loss
            g_optimizer.zero_grad()
            
            z = np.random.uniform(-1, 1, size = (batch_size, z_size))
            z = torch.from_numpy(z).float()
            if train_on_gpu:
                z = z.cuda()
            
            fake_images = G(z)
            D_fake = D(fake_images)
            g_loss = real_loss(D_fake)
            
            g_loss.backward()
            g_optimizer.step()
            
            
            # ===============================================
            #              END OF YOUR CODE
            # ===============================================

            # Print some loss stats
            if batch_i % print_every == 0:
                # append discriminator loss and generator loss
                losses.append((d_loss.item(), g_loss.item()))
                # print discriminator and generator loss
                print('Epoch [{:5d}/{:5d}] | d_loss: {:6.4f} | g_loss: {:6.4f}'.format(
                        epoch+1, n_epochs, d_loss.item(), g_loss.item()))


        ## AFTER EACH EPOCH##    
        # this code assumes your generator is named G, feel free to change the name
        # generate and save sample, fake images
        G.eval() # for generating samples
        samples_z = G(fixed_z)
        samples.append(samples_z)
        G.train() # back to training mode

    # Save training generator samples
    with open('train_samples.pkl', 'wb') as f:
        pkl.dump(samples, f)
    
    # finally return losses
    return losses

# %% [markdown]
# Set your number of training epochs and train your GAN!

# %%
# set number of epochs 
n_epochs = 15


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# call training function
losses = train(D, G, n_epochs=n_epochs)
# Out:
# Epoch [    1/   15] | d_loss: 1.3924 | g_loss: 5.0715
# Epoch [    1/   15] | d_loss: 1.0590 | g_loss: 1.3946
# Epoch [    1/   15] | d_loss: 1.0168 | g_loss: 1.5564
# Epoch [    1/   15] | d_loss: 1.0413 | g_loss: 2.0102
# Epoch [    1/   15] | d_loss: 1.0599 | g_loss: 2.0178
# Epoch [    1/   15] | d_loss: 1.2832 | g_loss: 1.1073
# Epoch [    1/   15] | d_loss: 0.9236 | g_loss: 1.7773
# Epoch [    1/   15] | d_loss: 1.0247 | g_loss: 2.5967
# Epoch [    1/   15] | d_loss: 1.3738 | g_loss: 0.9439
# Epoch [    1/   15] | d_loss: 1.4401 | g_loss: 2.6634
# Epoch [    1/   15] | d_loss: 0.9285 | g_loss: 2.0839
# Epoch [    1/   15] | d_loss: 1.1977 | g_loss: 2.4536
# Epoch [    1/   15] | d_loss: 1.1722 | g_loss: 1.6587
# Epoch [    1/   15] | d_loss: 0.7572 | g_loss: 2.4869
# Epoch [    1/   15] | d_loss: 1.1269 | g_loss: 3.4115
# Epoch [    1/   15] | d_loss: 1.2193 | g_loss: 1.9137
# Epoch [    1/   15] | d_loss: 1.1712 | g_loss: 2.1067
# Epoch [    1/   15] | d_loss: 0.9895 | g_loss: 2.4600
# Epoch [    1/   15] | d_loss: 2.2137 | g_loss: 3.8301
# Epoch [    1/   15] | d_loss: 1.2610 | g_loss: 2.7472
# Epoch [    1/   15] | d_loss: 0.8256 | g_loss: 3.0759
# Epoch [    1/   15] | d_loss: 0.5677 | g_loss: 0.9211
# Epoch [    1/   15] | d_loss: 0.7543 | g_loss: 2.9896
# Epoch [    1/   15] | d_loss: 1.0509 | g_loss: 1.7136
# Epoch [    1/   15] | d_loss: 0.9429 | g_loss: 2.7344
# Epoch [    1/   15] | d_loss: 0.6182 | g_loss: 3.4515
# Epoch [    1/   15] | d_loss: 1.0558 | g_loss: 3.0632
# Epoch [    1/   15] | d_loss: 0.6390 | g_loss: 2.7585
# Epoch [    1/   15] | d_loss: 0.9026 | g_loss: 3.8780
# Epoch [    1/   15] | d_loss: 0.8023 | g_loss: 2.6119
# Epoch [    1/   15] | d_loss: 0.9324 | g_loss: 1.2990
# Epoch [    1/   15] | d_loss: 0.7920 | g_loss: 3.8093
# Epoch [    1/   15] | d_loss: 0.4462 | g_loss: 2.1725
# Epoch [    1/   15] | d_loss: 0.7940 | g_loss: 2.5090
# Epoch [    1/   15] | d_loss: 0.8053 | g_loss: 2.7476
# Epoch [    1/   15] | d_loss: 0.8072 | g_loss: 4.5885
# Epoch [    1/   15] | d_loss: 0.3238 | g_loss: 2.7249
# Epoch [    1/   15] | d_loss: 0.6961 | g_loss: 2.6664
# Epoch [    1/   15] | d_loss: 0.7325 | g_loss: 1.8142
# Epoch [    1/   15] | d_loss: 0.9951 | g_loss: 3.7624
# Epoch [    1/   15] | d_loss: 0.8496 | g_loss: 2.3392
# Epoch [    1/   15] | d_loss: 1.0131 | g_loss: 4.3668
# Epoch [    1/   15] | d_loss: 0.9126 | g_loss: 1.8720
# Epoch [    1/   15] | d_loss: 0.6824 | g_loss: 2.9520
# Epoch [    1/   15] | d_loss: 0.7398 | g_loss: 4.2821
# Epoch [    1/   15] | d_loss: 0.7579 | g_loss: 4.3228
# Epoch [    1/   15] | d_loss: 0.6795 | g_loss: 2.6230
# Epoch [    1/   15] | d_loss: 0.7509 | g_loss: 2.8379
# Epoch [    1/   15] | d_loss: 0.1851 | g_loss: 3.1674
# Epoch [    1/   15] | d_loss: 0.7164 | g_loss: 2.4527
# Epoch [    1/   15] | d_loss: 0.8012 | g_loss: 3.1998
# Epoch [    1/   15] | d_loss: 1.3013 | g_loss: 4.5518
# Epoch [    1/   15] | d_loss: 0.6865 | g_loss: 4.1193
# Epoch [    1/   15] | d_loss: 0.8215 | g_loss: 1.7209
# Epoch [    1/   15] | d_loss: 0.5063 | g_loss: 3.3774
# Epoch [    1/   15] | d_loss: 0.5923 | g_loss: 2.8526
# Epoch [    1/   15] | d_loss: 0.8011 | g_loss: 3.0150
# Epoch [    1/   15] | d_loss: 0.8507 | g_loss: 5.8261
# Epoch [    1/   15] | d_loss: 0.5043 | g_loss: 2.8586
# Epoch [    1/   15] | d_loss: 1.0177 | g_loss: 4.8644
# Epoch [    1/   15] | d_loss: 0.5599 | g_loss: 2.8454
# Epoch [    1/   15] | d_loss: 0.4199 | g_loss: 3.7308
# Epoch [    1/   15] | d_loss: 0.6739 | g_loss: 2.9878
# Epoch [    1/   15] | d_loss: 0.7210 | g_loss: 1.5924
# Epoch [    1/   15] | d_loss: 0.5908 | g_loss: 3.3955
# Epoch [    1/   15] | d_loss: 0.6137 | g_loss: 2.3502
# Epoch [    1/   15] | d_loss: 1.1330 | g_loss: 1.3766
# Epoch [    1/   15] | d_loss: 0.6307 | g_loss: 5.3165
# Epoch [    1/   15] | d_loss: 0.4038 | g_loss: 3.1819
# Epoch [    1/   15] | d_loss: 0.4820 | g_loss: 3.1572
# Epoch [    1/   15] | d_loss: 0.6244 | g_loss: 3.3548
# Epoch [    1/   15] | d_loss: 0.7011 | g_loss: 2.5248
# Epoch [    2/   15] | d_loss: 1.2816 | g_loss: 1.9688
# Epoch [    2/   15] | d_loss: 0.5884 | g_loss: 3.4802
# Epoch [    2/   15] | d_loss: 0.4314 | g_loss: 2.7946
# Epoch [    2/   15] | d_loss: 1.0475 | g_loss: 2.9081
# Epoch [    2/   15] | d_loss: 0.6941 | g_loss: 3.2105
# Epoch [    2/   15] | d_loss: 0.9597 | g_loss: 2.6172
# Epoch [    2/   15] | d_loss: 0.5075 | g_loss: 1.8779
# Epoch [    2/   15] | d_loss: 0.3517 | g_loss: 4.4283
# Epoch [    2/   15] | d_loss: 0.9418 | g_loss: 4.0237
# Epoch [    2/   15] | d_loss: 0.4391 | g_loss: 3.4928
# Epoch [    2/   15] | d_loss: 0.8394 | g_loss: 1.9805
# Epoch [    2/   15] | d_loss: 0.9114 | g_loss: 1.6856
# Epoch [    2/   15] | d_loss: 0.5913 | g_loss: 3.6360
# Epoch [    2/   15] | d_loss: 0.9828 | g_loss: 1.9761
# Epoch [    2/   15] | d_loss: 1.5155 | g_loss: 4.3714
# Epoch [    2/   15] | d_loss: 1.0974 | g_loss: 3.6833
# Epoch [    2/   15] | d_loss: 0.6143 | g_loss: 3.2843
# Epoch [    2/   15] | d_loss: 1.1143 | g_loss: 4.7244
# Epoch [    2/   15] | d_loss: 0.7372 | g_loss: 2.6304
# Epoch [    2/   15] | d_loss: 0.6320 | g_loss: 3.0668
# Epoch [    2/   15] | d_loss: 0.5488 | g_loss: 3.6077
# Epoch [    2/   15] | d_loss: 1.3155 | g_loss: 5.6117
# Epoch [    2/   15] | d_loss: 0.4038 | g_loss: 2.0500
# Epoch [    2/   15] | d_loss: 0.6207 | g_loss: 2.4225
# Epoch [    2/   15] | d_loss: 0.4863 | g_loss: 3.3917
# Epoch [    2/   15] | d_loss: 0.2778 | g_loss: 3.9765
# Epoch [    2/   15] | d_loss: 0.2220 | g_loss: 3.5356
# Epoch [    2/   15] | d_loss: 0.2053 | g_loss: 3.8162
# Epoch [    2/   15] | d_loss: 0.4017 | g_loss: 1.5423
# Epoch [    2/   15] | d_loss: 0.4424 | g_loss: 2.6153
# Epoch [    2/   15] | d_loss: 0.5919 | g_loss: 4.8371
# Epoch [    2/   15] | d_loss: 0.6526 | g_loss: 3.4790
# Epoch [    2/   15] | d_loss: 0.6620 | g_loss: 5.7036
# Epoch [    2/   15] | d_loss: 0.3152 | g_loss: 3.4640
# Epoch [    2/   15] | d_loss: 0.9516 | g_loss: 1.2632
# Epoch [    2/   15] | d_loss: 0.5367 | g_loss: 3.5662
# Epoch [    2/   15] | d_loss: 1.1871 | g_loss: 0.8863
# Epoch [    2/   15] | d_loss: 0.6563 | g_loss: 2.9766
# Epoch [    2/   15] | d_loss: 0.5450 | g_loss: 4.0258
# Epoch [    2/   15] | d_loss: 1.5671 | g_loss: 4.8098
# Epoch [    2/   15] | d_loss: 0.9457 | g_loss: 3.0535
# Epoch [    2/   15] | d_loss: 0.5844 | g_loss: 1.6665
# Epoch [    2/   15] | d_loss: 0.6161 | g_loss: 1.8316
# Epoch [    2/   15] | d_loss: 0.3911 | g_loss: 2.8449
# Epoch [    2/   15] | d_loss: 0.8585 | g_loss: 3.1618
# Epoch [    2/   15] | d_loss: 0.3359 | g_loss: 3.8507
# Epoch [    2/   15] | d_loss: 0.3611 | g_loss: 3.2795
# Epoch [    2/   15] | d_loss: 1.1889 | g_loss: 4.5460
# Epoch [    2/   15] | d_loss: 0.9339 | g_loss: 2.9653
# Epoch [    2/   15] | d_loss: 0.3041 | g_loss: 2.9888
# Epoch [    2/   15] | d_loss: 0.7914 | g_loss: 4.3969
# Epoch [    2/   15] | d_loss: 0.5010 | g_loss: 3.1640
# Epoch [    2/   15] | d_loss: 0.9866 | g_loss: 4.1626
# Epoch [    2/   15] | d_loss: 0.3795 | g_loss: 3.0762
# Epoch [    2/   15] | d_loss: 0.5433 | g_loss: 4.1388
# Epoch [    2/   15] | d_loss: 0.4607 | g_loss: 2.3710
# Epoch [    2/   15] | d_loss: 0.5816 | g_loss: 2.2923
# Epoch [    2/   15] | d_loss: 1.3571 | g_loss: 3.6849
# Epoch [    2/   15] | d_loss: 0.3867 | g_loss: 1.3237
# Epoch [    2/   15] | d_loss: 0.6163 | g_loss: 3.0646
# Epoch [    2/   15] | d_loss: 0.8496 | g_loss: 2.1656
# Epoch [    2/   15] | d_loss: 0.4263 | g_loss: 3.1466
# Epoch [    2/   15] | d_loss: 0.2228 | g_loss: 3.9249
# Epoch [    2/   15] | d_loss: 0.8001 | g_loss: 2.2634
# Epoch [    2/   15] | d_loss: 0.8003 | g_loss: 4.1708
# Epoch [    2/   15] | d_loss: 0.4635 | g_loss: 3.6947
# Epoch [    2/   15] | d_loss: 0.2047 | g_loss: 5.4795
# Epoch [    2/   15] | d_loss: 0.6455 | g_loss: 4.9020
# Epoch [    2/   15] | d_loss: 1.1985 | g_loss: 3.0039
# Epoch [    2/   15] | d_loss: 0.6404 | g_loss: 2.4217
# Epoch [    2/   15] | d_loss: 1.0433 | g_loss: 2.4807
# Epoch [    2/   15] | d_loss: 0.4915 | g_loss: 2.8897
# Epoch [    3/   15] | d_loss: 2.7538 | g_loss: 2.7915
# Epoch [    3/   15] | d_loss: 0.6017 | g_loss: 4.0583
# Epoch [    3/   15] | d_loss: 1.2054 | g_loss: 4.8450
# Epoch [    3/   15] | d_loss: 0.8921 | g_loss: 2.5477
# Epoch [    3/   15] | d_loss: 1.3139 | g_loss: 2.5884
# Epoch [    3/   15] | d_loss: 0.4509 | g_loss: 2.0956
# Epoch [    3/   15] | d_loss: 0.4277 | g_loss: 3.2116
# Epoch [    3/   15] | d_loss: 0.9048 | g_loss: 5.4832
# Epoch [    3/   15] | d_loss: 0.3417 | g_loss: 3.8361
# Epoch [    3/   15] | d_loss: 0.5252 | g_loss: 3.3062
# Epoch [    3/   15] | d_loss: 0.1362 | g_loss: 3.2144
# Epoch [    3/   15] | d_loss: 0.9987 | g_loss: 1.5357
# Epoch [    3/   15] | d_loss: 1.0943 | g_loss: 2.2198
# Epoch [    3/   15] | d_loss: 1.0916 | g_loss: 4.8127
# Epoch [    3/   15] | d_loss: 0.5253 | g_loss: 4.3035
# Epoch [    3/   15] | d_loss: 0.9224 | g_loss: 1.4741
# Epoch [    3/   15] | d_loss: 0.3749 | g_loss: 3.7354
# Epoch [    3/   15] | d_loss: 2.3982 | g_loss: 3.4415
# Epoch [    3/   15] | d_loss: 0.7032 | g_loss: 4.2679
# Epoch [    3/   15] | d_loss: 0.3179 | g_loss: 4.2454
# Epoch [    3/   15] | d_loss: 0.5047 | g_loss: 1.1577
# Epoch [    3/   15] | d_loss: 0.1358 | g_loss: 4.5964
# Epoch [    3/   15] | d_loss: 1.2405 | g_loss: 2.6466
# Epoch [    3/   15] | d_loss: 0.7290 | g_loss: 4.3480
# Epoch [    3/   15] | d_loss: 0.4456 | g_loss: 3.5967
# Epoch [    3/   15] | d_loss: 0.1287 | g_loss: 5.4249
# Epoch [    3/   15] | d_loss: 0.5726 | g_loss: 3.0257
# Epoch [    3/   15] | d_loss: 0.8898 | g_loss: 3.7493
# Epoch [    3/   15] | d_loss: 0.7701 | g_loss: 3.2530
# Epoch [    3/   15] | d_loss: 0.5373 | g_loss: 3.4415
# Epoch [    3/   15] | d_loss: 0.4330 | g_loss: 2.6180
# Epoch [    3/   15] | d_loss: 0.5256 | g_loss: 2.9541
# Epoch [    3/   15] | d_loss: 0.2655 | g_loss: 3.7997
# Epoch [    3/   15] | d_loss: 0.5304 | g_loss: 2.1828
# Epoch [    3/   15] | d_loss: 0.8997 | g_loss: 1.8686
# Epoch [    3/   15] | d_loss: 1.1143 | g_loss: 1.3235
# Epoch [    3/   15] | d_loss: 0.2663 | g_loss: 2.3013
# Epoch [    3/   15] | d_loss: 0.6970 | g_loss: 2.0967
# Epoch [    3/   15] | d_loss: 0.6877 | g_loss: 4.3087
# Epoch [    3/   15] | d_loss: 0.5189 | g_loss: 1.5688
# Epoch [    3/   15] | d_loss: 0.5523 | g_loss: 4.0482
# Epoch [    3/   15] | d_loss: 0.3471 | g_loss: 2.6186
# Epoch [    3/   15] | d_loss: 2.1271 | g_loss: 0.6830
# Epoch [    3/   15] | d_loss: 0.6357 | g_loss: 4.1200
# Epoch [    3/   15] | d_loss: 0.4982 | g_loss: 3.0292
# Epoch [    3/   15] | d_loss: 0.3969 | g_loss: 3.3656
# Epoch [    3/   15] | d_loss: 1.0262 | g_loss: 3.7239
# Epoch [    3/   15] | d_loss: 0.4040 | g_loss: 7.4620
# Epoch [    3/   15] | d_loss: 0.4717 | g_loss: 1.7502
# Epoch [    3/   15] | d_loss: 0.4203 | g_loss: 4.1892
# Epoch [    3/   15] | d_loss: 1.3165 | g_loss: 2.5480
# Epoch [    3/   15] | d_loss: 0.3055 | g_loss: 2.8115
# Epoch [    3/   15] | d_loss: 0.4851 | g_loss: 3.5370
# Epoch [    3/   15] | d_loss: 0.3709 | g_loss: 2.6989
# Epoch [    3/   15] | d_loss: 0.6925 | g_loss: 2.1607
# Epoch [    3/   15] | d_loss: 0.5615 | g_loss: 2.4103
# Epoch [    3/   15] | d_loss: 0.8318 | g_loss: 2.4530
# Epoch [    3/   15] | d_loss: 0.1897 | g_loss: 2.1366
# Epoch [    3/   15] | d_loss: 0.2138 | g_loss: 5.7526
# Epoch [    3/   15] | d_loss: 1.2387 | g_loss: 5.2555
# Epoch [    3/   15] | d_loss: 0.3109 | g_loss: 3.8658
# Epoch [    3/   15] | d_loss: 0.5166 | g_loss: 2.5300
# Epoch [    3/   15] | d_loss: 0.7904 | g_loss: 4.7986
# Epoch [    3/   15] | d_loss: 0.4559 | g_loss: 2.5858
# Epoch [    3/   15] | d_loss: 0.5792 | g_loss: 4.0611
# Epoch [    3/   15] | d_loss: 0.6453 | g_loss: 2.1921
# Epoch [    3/   15] | d_loss: 1.1789 | g_loss: 4.2515
# Epoch [    3/   15] | d_loss: 0.5284 | g_loss: 2.3968
# Epoch [    3/   15] | d_loss: 0.5420 | g_loss: 5.2822
# Epoch [    3/   15] | d_loss: 0.5550 | g_loss: 2.9342
# Epoch [    3/   15] | d_loss: 0.6081 | g_loss: 2.8806
# Epoch [    3/   15] | d_loss: 0.4781 | g_loss: 2.4272
# Epoch [    4/   15] | d_loss: 0.5183 | g_loss: 3.0793
# Epoch [    4/   15] | d_loss: 0.3462 | g_loss: 3.9715
# Epoch [    4/   15] | d_loss: 0.3758 | g_loss: 3.0753
# Epoch [    4/   15] | d_loss: 0.7922 | g_loss: 6.1057
# Epoch [    4/   15] | d_loss: 0.3693 | g_loss: 3.2402
# Epoch [    4/   15] | d_loss: 0.1953 | g_loss: 2.4778
# Epoch [    4/   15] | d_loss: 0.4854 | g_loss: 2.3171
# Epoch [    4/   15] | d_loss: 0.4676 | g_loss: 3.4836
# Epoch [    4/   15] | d_loss: 0.2966 | g_loss: 4.6597
# Epoch [    4/   15] | d_loss: 0.3453 | g_loss: 4.5613
# Epoch [    4/   15] | d_loss: 0.4614 | g_loss: 3.2778
# Epoch [    4/   15] | d_loss: 0.3820 | g_loss: 2.3303
# Epoch [    4/   15] | d_loss: 0.2597 | g_loss: 1.6195
# Epoch [    4/   15] | d_loss: 0.4779 | g_loss: 3.3325
# Epoch [    4/   15] | d_loss: 0.3928 | g_loss: 3.9746
# Epoch [    4/   15] | d_loss: 0.3695 | g_loss: 3.1895
# Epoch [    4/   15] | d_loss: 0.7793 | g_loss: 3.0440
# Epoch [    4/   15] | d_loss: 0.1942 | g_loss: 2.2292
# Epoch [    4/   15] | d_loss: 0.1216 | g_loss: 4.1837
# Epoch [    4/   15] | d_loss: 0.2813 | g_loss: 5.1565
# Epoch [    4/   15] | d_loss: 0.4566 | g_loss: 2.0112
# Epoch [    4/   15] | d_loss: 0.6966 | g_loss: 5.1050
# Epoch [    4/   15] | d_loss: 0.2297 | g_loss: 5.2901
# Epoch [    4/   15] | d_loss: 0.3177 | g_loss: 2.5454
# Epoch [    4/   15] | d_loss: 0.3258 | g_loss: 2.4082
# Epoch [    4/   15] | d_loss: 0.5590 | g_loss: 3.0170
# Epoch [    4/   15] | d_loss: 0.2290 | g_loss: 5.7975
# Epoch [    4/   15] | d_loss: 0.4208 | g_loss: 2.4405
# Epoch [    4/   15] | d_loss: 0.3883 | g_loss: 3.1524
# Epoch [    4/   15] | d_loss: 0.7896 | g_loss: 3.3733
# Epoch [    4/   15] | d_loss: 0.4594 | g_loss: 2.7627
# Epoch [    4/   15] | d_loss: 0.3674 | g_loss: 3.9125
# Epoch [    4/   15] | d_loss: 0.3236 | g_loss: 1.8820
# Epoch [    4/   15] | d_loss: 0.5017 | g_loss: 1.9524
# Epoch [    4/   15] | d_loss: 0.9275 | g_loss: 2.5768
# Epoch [    4/   15] | d_loss: 0.2282 | g_loss: 2.2989
# Epoch [    4/   15] | d_loss: 0.5404 | g_loss: 3.4578
# Epoch [    4/   15] | d_loss: 0.7814 | g_loss: 2.5202
# Epoch [    4/   15] | d_loss: 0.3253 | g_loss: 3.0811
# Epoch [    4/   15] | d_loss: 0.8736 | g_loss: 3.7807
# Epoch [    4/   15] | d_loss: 0.4989 | g_loss: 3.8598
# Epoch [    4/   15] | d_loss: 0.4104 | g_loss: 3.6475
# Epoch [    4/   15] | d_loss: 0.2223 | g_loss: 5.1606
# Epoch [    4/   15] | d_loss: 0.4351 | g_loss: 4.4329
# Epoch [    4/   15] | d_loss: 0.8278 | g_loss: 3.2394
# Epoch [    4/   15] | d_loss: 0.9320 | g_loss: 2.7796
# Epoch [    4/   15] | d_loss: 0.2068 | g_loss: 4.1971
# Epoch [    4/   15] | d_loss: 0.7841 | g_loss: 3.2803
# Epoch [    4/   15] | d_loss: 0.6930 | g_loss: 2.5735
# Epoch [    4/   15] | d_loss: 0.2587 | g_loss: 1.3186
# Epoch [    4/   15] | d_loss: 0.4967 | g_loss: 4.4364
# Epoch [    4/   15] | d_loss: 0.3784 | g_loss: 3.4966
# Epoch [    4/   15] | d_loss: 1.2887 | g_loss: 4.8476
# Epoch [    4/   15] | d_loss: 1.2499 | g_loss: 4.7131
# Epoch [    4/   15] | d_loss: 0.3301 | g_loss: 2.7426
# Epoch [    4/   15] | d_loss: 0.1458 | g_loss: 3.2851
# Epoch [    4/   15] | d_loss: 0.3263 | g_loss: 6.0341
# Epoch [    4/   15] | d_loss: 0.3348 | g_loss: 2.5250
# Epoch [    4/   15] | d_loss: 1.2112 | g_loss: 8.8005
# Epoch [    4/   15] | d_loss: 0.3546 | g_loss: 3.9082
# Epoch [    4/   15] | d_loss: 0.4818 | g_loss: 1.6987
# Epoch [    4/   15] | d_loss: 0.3039 | g_loss: 2.4109
# Epoch [    4/   15] | d_loss: 0.1421 | g_loss: 3.8025
# Epoch [    4/   15] | d_loss: 0.3422 | g_loss: 5.2728
# Epoch [    4/   15] | d_loss: 0.1487 | g_loss: 2.8378
# Epoch [    4/   15] | d_loss: 1.9173 | g_loss: 4.9330
# Epoch [    4/   15] | d_loss: 0.6676 | g_loss: 4.8869
# Epoch [    4/   15] | d_loss: 0.6251 | g_loss: 3.5008
# Epoch [    4/   15] | d_loss: 1.0172 | g_loss: 2.2844
# Epoch [    4/   15] | d_loss: 0.3487 | g_loss: 2.8954
# Epoch [    4/   15] | d_loss: 0.7868 | g_loss: 4.8520
# Epoch [    4/   15] | d_loss: 0.1905 | g_loss: 4.4888
# Epoch [    5/   15] | d_loss: 1.9390 | g_loss: 9.6855
# Epoch [    5/   15] | d_loss: 0.3095 | g_loss: 3.0581
# Epoch [    5/   15] | d_loss: 0.6995 | g_loss: 2.2993
# Epoch [    5/   15] | d_loss: 0.4850 | g_loss: 3.7251
# Epoch [    5/   15] | d_loss: 0.6069 | g_loss: 3.0377
# Epoch [    5/   15] | d_loss: 0.1543 | g_loss: 4.6851
# Epoch [    5/   15] | d_loss: 0.8389 | g_loss: 3.1519
# Epoch [    5/   15] | d_loss: 0.2325 | g_loss: 3.5267
# Epoch [    5/   15] | d_loss: 0.4009 | g_loss: 3.1835
# Epoch [    5/   15] | d_loss: 0.8376 | g_loss: 5.9291
# Epoch [    5/   15] | d_loss: 0.4084 | g_loss: 4.6148
# Epoch [    5/   15] | d_loss: 0.9429 | g_loss: 5.4813
# Epoch [    5/   15] | d_loss: 0.6148 | g_loss: 3.7242
# Epoch [    5/   15] | d_loss: 0.2636 | g_loss: 3.7532
# Epoch [    5/   15] | d_loss: 0.5440 | g_loss: 1.8768
# Epoch [    5/   15] | d_loss: 0.4882 | g_loss: 2.8294
# Epoch [    5/   15] | d_loss: 0.3495 | g_loss: 3.4885
# Epoch [    5/   15] | d_loss: 0.2441 | g_loss: 2.3244
# Epoch [    5/   15] | d_loss: 0.2333 | g_loss: 3.3786
# Epoch [    5/   15] | d_loss: 0.5110 | g_loss: 6.1724
# Epoch [    5/   15] | d_loss: 0.3854 | g_loss: 6.2712
# Epoch [    5/   15] | d_loss: 1.0648 | g_loss: 2.9670
# Epoch [    5/   15] | d_loss: 0.3551 | g_loss: 3.5592
# Epoch [    5/   15] | d_loss: 0.2694 | g_loss: 5.7353
# Epoch [    5/   15] | d_loss: 0.4045 | g_loss: 5.1486
# Epoch [    5/   15] | d_loss: 0.5041 | g_loss: 2.6237
# Epoch [    5/   15] | d_loss: 0.4552 | g_loss: 3.7968
# Epoch [    5/   15] | d_loss: 0.5333 | g_loss: 3.0194
# Epoch [    5/   15] | d_loss: 0.3307 | g_loss: 3.6636
# Epoch [    5/   15] | d_loss: 0.5697 | g_loss: 5.8892
# Epoch [    5/   15] | d_loss: 0.4865 | g_loss: 5.3102
# Epoch [    5/   15] | d_loss: 0.3924 | g_loss: 4.5037
# Epoch [    5/   15] | d_loss: 0.5492 | g_loss: 2.9664
# Epoch [    5/   15] | d_loss: 0.7956 | g_loss: 3.9260
# Epoch [    5/   15] | d_loss: 0.3533 | g_loss: 4.6951
# Epoch [    5/   15] | d_loss: 0.4568 | g_loss: 3.2216
# Epoch [    5/   15] | d_loss: 0.7955 | g_loss: 3.5668
# Epoch [    5/   15] | d_loss: 0.5571 | g_loss: 1.6523
# Epoch [    5/   15] | d_loss: 0.1830 | g_loss: 2.7009
# Epoch [    5/   15] | d_loss: 0.5549 | g_loss: 4.9995
# Epoch [    5/   15] | d_loss: 0.2250 | g_loss: 4.5730
# Epoch [    5/   15] | d_loss: 0.1795 | g_loss: 4.3327
# Epoch [    5/   15] | d_loss: 0.1889 | g_loss: 3.6704
# Epoch [    5/   15] | d_loss: 0.6209 | g_loss: 3.6453
# Epoch [    5/   15] | d_loss: 0.6074 | g_loss: 5.5490
# Epoch [    5/   15] | d_loss: 0.2171 | g_loss: 3.7420
# Epoch [    5/   15] | d_loss: 0.6263 | g_loss: 2.6173
# Epoch [    5/   15] | d_loss: 1.4006 | g_loss: 4.3641
# Epoch [    5/   15] | d_loss: 0.5716 | g_loss: 3.3268
# Epoch [    5/   15] | d_loss: 1.0092 | g_loss: 2.6059
# Epoch [    5/   15] | d_loss: 0.5730 | g_loss: 4.4781
# Epoch [    5/   15] | d_loss: 0.4007 | g_loss: 3.9129
# Epoch [    5/   15] | d_loss: 1.0093 | g_loss: 1.4013
# Epoch [    5/   15] | d_loss: 0.5371 | g_loss: 4.0878
# Epoch [    5/   15] | d_loss: 0.4527 | g_loss: 5.2832
# Epoch [    5/   15] | d_loss: 1.1849 | g_loss: 6.0226
# Epoch [    5/   15] | d_loss: 0.2803 | g_loss: 3.3468
# Epoch [    5/   15] | d_loss: 1.0109 | g_loss: 1.7133
# Epoch [    5/   15] | d_loss: 0.3678 | g_loss: 2.1242
# Epoch [    5/   15] | d_loss: 0.3312 | g_loss: 2.8212
# Epoch [    5/   15] | d_loss: 0.2947 | g_loss: 4.0553
# Epoch [    5/   15] | d_loss: 0.8603 | g_loss: 2.9581
# Epoch [    5/   15] | d_loss: 0.1708 | g_loss: 4.2202
# Epoch [    5/   15] | d_loss: 0.4404 | g_loss: 5.2075
# Epoch [    5/   15] | d_loss: 0.1238 | g_loss: 4.3711
# Epoch [    5/   15] | d_loss: 0.3307 | g_loss: 1.8935
# Epoch [    5/   15] | d_loss: 0.3713 | g_loss: 3.9065
# Epoch [    5/   15] | d_loss: 0.4296 | g_loss: 2.6185
# Epoch [    5/   15] | d_loss: 0.3068 | g_loss: 4.1423
# Epoch [    5/   15] | d_loss: 0.4037 | g_loss: 4.8596
# Epoch [    5/   15] | d_loss: 0.0658 | g_loss: 5.5881
# Epoch [    5/   15] | d_loss: 0.6655 | g_loss: 4.6295
# Epoch [    6/   15] | d_loss: 0.5847 | g_loss: 3.5313
# Epoch [    6/   15] | d_loss: 0.5202 | g_loss: 2.1603
# Epoch [    6/   15] | d_loss: 1.9056 | g_loss: 0.2686
# Epoch [    6/   15] | d_loss: 0.4803 | g_loss: 3.6185
# Epoch [    6/   15] | d_loss: 0.1959 | g_loss: 4.9984
# Epoch [    6/   15] | d_loss: 0.3144 | g_loss: 4.5998
# Epoch [    6/   15] | d_loss: 0.2940 | g_loss: 5.8728
# Epoch [    6/   15] | d_loss: 0.2152 | g_loss: 3.4331
# Epoch [    6/   15] | d_loss: 0.1225 | g_loss: 4.1153
# Epoch [    6/   15] | d_loss: 0.2349 | g_loss: 3.3337
# Epoch [    6/   15] | d_loss: 0.1550 | g_loss: 6.0947
# Epoch [    6/   15] | d_loss: 0.2381 | g_loss: 2.4297
# Epoch [    6/   15] | d_loss: 0.1874 | g_loss: 4.3869
# Epoch [    6/   15] | d_loss: 0.2924 | g_loss: 2.8388
# Epoch [    6/   15] | d_loss: 1.0175 | g_loss: 1.2071
# Epoch [    6/   15] | d_loss: 0.1674 | g_loss: 4.5555
# Epoch [    6/   15] | d_loss: 0.1209 | g_loss: 3.9898
# Epoch [    6/   15] | d_loss: 0.3682 | g_loss: 4.5963
# Epoch [    6/   15] | d_loss: 0.3408 | g_loss: 3.3490
# Epoch [    6/   15] | d_loss: 0.6379 | g_loss: 6.6949
# Epoch [    6/   15] | d_loss: 0.4635 | g_loss: 5.0774
# Epoch [    6/   15] | d_loss: 0.1540 | g_loss: 3.3680
# Epoch [    6/   15] | d_loss: 0.4935 | g_loss: 4.8935
# Epoch [    6/   15] | d_loss: 0.1606 | g_loss: 5.1504
# Epoch [    6/   15] | d_loss: 1.0569 | g_loss: 6.0238
# Epoch [    6/   15] | d_loss: 0.5269 | g_loss: 2.4539
# Epoch [    6/   15] | d_loss: 0.5896 | g_loss: 3.0241
# Epoch [    6/   15] | d_loss: 1.3970 | g_loss: 5.1995
# Epoch [    6/   15] | d_loss: 0.9701 | g_loss: 2.8215
# Epoch [    6/   15] | d_loss: 0.1473 | g_loss: 4.6087
# Epoch [    6/   15] | d_loss: 0.8753 | g_loss: 2.5289
# Epoch [    6/   15] | d_loss: 0.3641 | g_loss: 5.1770
# Epoch [    6/   15] | d_loss: 0.4300 | g_loss: 6.0525
# Epoch [    6/   15] | d_loss: 0.1848 | g_loss: 2.7650
# Epoch [    6/   15] | d_loss: 1.8063 | g_loss: 5.6845
# Epoch [    6/   15] | d_loss: 0.2749 | g_loss: 3.1980
# Epoch [    6/   15] | d_loss: 0.8950 | g_loss: 1.9270
# Epoch [    6/   15] | d_loss: 0.2224 | g_loss: 3.0109
# Epoch [    6/   15] | d_loss: 0.3861 | g_loss: 3.7431
# Epoch [    6/   15] | d_loss: 1.1667 | g_loss: 2.6999
# Epoch [    6/   15] | d_loss: 0.2144 | g_loss: 1.7235
# Epoch [    6/   15] | d_loss: 0.4486 | g_loss: 2.6939
# Epoch [    6/   15] | d_loss: 0.2505 | g_loss: 4.9037
# Epoch [    6/   15] | d_loss: 0.1355 | g_loss: 3.8615
# Epoch [    6/   15] | d_loss: 0.6154 | g_loss: 6.4309
# Epoch [    6/   15] | d_loss: 0.7923 | g_loss: 5.6840
# Epoch [    6/   15] | d_loss: 0.1869 | g_loss: 3.6023
# Epoch [    6/   15] | d_loss: 0.9757 | g_loss: 5.4031
# Epoch [    6/   15] | d_loss: 0.3292 | g_loss: 3.9927
# Epoch [    6/   15] | d_loss: 0.6605 | g_loss: 5.6954
# Epoch [    6/   15] | d_loss: 0.3577 | g_loss: 5.4453
# Epoch [    6/   15] | d_loss: 0.8964 | g_loss: 5.1152
# Epoch [    6/   15] | d_loss: 0.1240 | g_loss: 4.8647
# Epoch [    6/   15] | d_loss: 1.1647 | g_loss: 1.4757
# Epoch [    6/   15] | d_loss: 0.6964 | g_loss: 3.5931
# Epoch [    6/   15] | d_loss: 0.8591 | g_loss: 4.5046
# Epoch [    6/   15] | d_loss: 0.7047 | g_loss: 5.1560
# Epoch [    6/   15] | d_loss: 0.0914 | g_loss: 5.2626
# Epoch [    6/   15] | d_loss: 0.8071 | g_loss: 3.5604
# Epoch [    6/   15] | d_loss: 0.1106 | g_loss: 4.2686
# Epoch [    6/   15] | d_loss: 0.3294 | g_loss: 4.7534
# Epoch [    6/   15] | d_loss: 0.5021 | g_loss: 3.2457
# Epoch [    6/   15] | d_loss: 0.1931 | g_loss: 6.2801
# Epoch [    6/   15] | d_loss: 0.4088 | g_loss: 4.3000
# Epoch [    6/   15] | d_loss: 0.6541 | g_loss: 6.5809
# Epoch [    6/   15] | d_loss: 0.5534 | g_loss: 3.5840
# Epoch [    6/   15] | d_loss: 0.2790 | g_loss: 5.6476
# Epoch [    6/   15] | d_loss: 0.6471 | g_loss: 3.3702
# Epoch [    6/   15] | d_loss: 0.2918 | g_loss: 4.2984
# Epoch [    6/   15] | d_loss: 0.3187 | g_loss: 5.9671
# Epoch [    6/   15] | d_loss: 0.8743 | g_loss: 2.7882
# Epoch [    6/   15] | d_loss: 0.3185 | g_loss: 3.6566
# Epoch [    7/   15] | d_loss: 1.6043 | g_loss: 6.4520
# Epoch [    7/   15] | d_loss: 0.6418 | g_loss: 3.8990
# Epoch [    7/   15] | d_loss: 0.4758 | g_loss: 2.4175
# Epoch [    7/   15] | d_loss: 0.2372 | g_loss: 2.0124
# Epoch [    7/   15] | d_loss: 0.2520 | g_loss: 5.5331
# Epoch [    7/   15] | d_loss: 0.6192 | g_loss: 3.3361
# Epoch [    7/   15] | d_loss: 0.4325 | g_loss: 5.0885
# Epoch [    7/   15] | d_loss: 0.3931 | g_loss: 1.8255
# Epoch [    7/   15] | d_loss: 0.2678 | g_loss: 5.9639
# Epoch [    7/   15] | d_loss: 0.4794 | g_loss: 4.4741
# Epoch [    7/   15] | d_loss: 0.3029 | g_loss: 3.4388
# Epoch [    7/   15] | d_loss: 0.1741 | g_loss: 3.5351
# Epoch [    7/   15] | d_loss: 0.4079 | g_loss: 6.7136
# Epoch [    7/   15] | d_loss: 0.4042 | g_loss: 5.8022
# Epoch [    7/   15] | d_loss: 1.4719 | g_loss: 0.5088
# Epoch [    7/   15] | d_loss: 0.3669 | g_loss: 2.7922
# Epoch [    7/   15] | d_loss: 0.2326 | g_loss: 2.1082
# Epoch [    7/   15] | d_loss: 0.2415 | g_loss: 3.1570
# Epoch [    7/   15] | d_loss: 0.4369 | g_loss: 4.4109
# Epoch [    7/   15] | d_loss: 0.5795 | g_loss: 2.2736
# Epoch [    7/   15] | d_loss: 0.8147 | g_loss: 5.6047
# Epoch [    7/   15] | d_loss: 0.2267 | g_loss: 7.4727
# Epoch [    7/   15] | d_loss: 0.6227 | g_loss: 3.8940
# Epoch [    7/   15] | d_loss: 0.6693 | g_loss: 1.6971
# Epoch [    7/   15] | d_loss: 0.1122 | g_loss: 2.3744
# Epoch [    7/   15] | d_loss: 0.1711 | g_loss: 2.7779
# Epoch [    7/   15] | d_loss: 0.1846 | g_loss: 1.6149
# Epoch [    7/   15] | d_loss: 0.5926 | g_loss: 2.4277
# Epoch [    7/   15] | d_loss: 0.2633 | g_loss: 4.2846
# Epoch [    7/   15] | d_loss: 0.2802 | g_loss: 5.8298
# Epoch [    7/   15] | d_loss: 0.2964 | g_loss: 3.5941
# Epoch [    7/   15] | d_loss: 0.3373 | g_loss: 2.4467
# Epoch [    7/   15] | d_loss: 0.4423 | g_loss: 1.6959
# Epoch [    7/   15] | d_loss: 0.4138 | g_loss: 2.6149
# Epoch [    7/   15] | d_loss: 0.9493 | g_loss: 4.2848
# Epoch [    7/   15] | d_loss: 0.0167 | g_loss: 3.5346
# Epoch [    7/   15] | d_loss: 0.4760 | g_loss: 3.8719
# Epoch [    7/   15] | d_loss: 0.6084 | g_loss: 3.8041
# Epoch [    7/   15] | d_loss: 0.4162 | g_loss: 1.0883
# Epoch [    7/   15] | d_loss: 0.2236 | g_loss: 3.8327
# Epoch [    7/   15] | d_loss: 0.6415 | g_loss: 6.9201
# Epoch [    7/   15] | d_loss: 0.7457 | g_loss: 4.2545
# Epoch [    7/   15] | d_loss: 0.4213 | g_loss: 4.7413
# Epoch [    7/   15] | d_loss: 0.0824 | g_loss: 3.7582
# Epoch [    7/   15] | d_loss: 0.1319 | g_loss: 3.5291
# Epoch [    7/   15] | d_loss: 0.8488 | g_loss: 1.3383
# Epoch [    7/   15] | d_loss: 0.1440 | g_loss: 2.5471
# Epoch [    7/   15] | d_loss: 0.1197 | g_loss: 4.9937
# Epoch [    7/   15] | d_loss: 0.7110 | g_loss: 8.4399
# Epoch [    7/   15] | d_loss: 0.7499 | g_loss: 6.0844
# Epoch [    7/   15] | d_loss: 0.1182 | g_loss: 5.5355
# Epoch [    7/   15] | d_loss: 0.6295 | g_loss: 5.0911
# Epoch [    7/   15] | d_loss: 1.2442 | g_loss: 3.7316
# Epoch [    7/   15] | d_loss: 0.3603 | g_loss: 4.9690
# Epoch [    7/   15] | d_loss: 1.7001 | g_loss: 7.5299
# Epoch [    7/   15] | d_loss: 0.2027 | g_loss: 8.1591
# Epoch [    7/   15] | d_loss: 0.0828 | g_loss: 5.7690
# Epoch [    7/   15] | d_loss: 0.9009 | g_loss: 6.2383
# Epoch [    7/   15] | d_loss: 0.1080 | g_loss: 4.9505
# Epoch [    7/   15] | d_loss: 1.1090 | g_loss: 8.3016
# Epoch [    7/   15] | d_loss: 0.4055 | g_loss: 3.9920
# Epoch [    7/   15] | d_loss: 0.4361 | g_loss: 3.8376
# Epoch [    7/   15] | d_loss: 0.3185 | g_loss: 3.7905
# Epoch [    7/   15] | d_loss: 0.3809 | g_loss: 5.2069
# Epoch [    7/   15] | d_loss: 0.0983 | g_loss: 4.2267
# Epoch [    7/   15] | d_loss: 0.4038 | g_loss: 4.7623
# Epoch [    7/   15] | d_loss: 0.4187 | g_loss: 2.1436
# Epoch [    7/   15] | d_loss: 0.2451 | g_loss: 4.1560
# Epoch [    7/   15] | d_loss: 0.8798 | g_loss: 2.7184
# Epoch [    7/   15] | d_loss: 0.3164 | g_loss: 4.6994
# Epoch [    7/   15] | d_loss: 0.8895 | g_loss: 3.8151
# Epoch [    7/   15] | d_loss: 0.4232 | g_loss: 5.1912
# Epoch [    8/   15] | d_loss: 0.7226 | g_loss: 5.6384
# Epoch [    8/   15] | d_loss: 0.1855 | g_loss: 3.7033
# Epoch [    8/   15] | d_loss: 0.1425 | g_loss: 8.2435
# Epoch [    8/   15] | d_loss: 0.5764 | g_loss: 2.2943
# Epoch [    8/   15] | d_loss: 0.3447 | g_loss: 9.9413
# Epoch [    8/   15] | d_loss: 0.6625 | g_loss: 6.2277
# Epoch [    8/   15] | d_loss: 0.7585 | g_loss: 3.5763
# Epoch [    8/   15] | d_loss: 0.5622 | g_loss: 5.7222
# Epoch [    8/   15] | d_loss: 0.0960 | g_loss: 3.0987
# Epoch [    8/   15] | d_loss: 0.3448 | g_loss: 3.8085
# Epoch [    8/   15] | d_loss: 0.1361 | g_loss: 3.6796
# Epoch [    8/   15] | d_loss: 0.0712 | g_loss: 3.6662
# Epoch [    8/   15] | d_loss: 0.2086 | g_loss: 2.6588
# Epoch [    8/   15] | d_loss: 0.1052 | g_loss: 2.7908
# Epoch [    8/   15] | d_loss: 0.0968 | g_loss: 5.3186
# Epoch [    8/   15] | d_loss: 0.3565 | g_loss: 5.1386
# Epoch [    8/   15] | d_loss: 0.9841 | g_loss: 6.9104
# Epoch [    8/   15] | d_loss: 0.2017 | g_loss: 6.9616
# Epoch [    8/   15] | d_loss: 0.6264 | g_loss: 4.0553
# Epoch [    8/   15] | d_loss: 0.2364 | g_loss: 3.9748
# Epoch [    8/   15] | d_loss: 0.5639 | g_loss: 7.4702
# Epoch [    8/   15] | d_loss: 0.1386 | g_loss: 3.8177
# Epoch [    8/   15] | d_loss: 0.3261 | g_loss: 7.2281
# Epoch [    8/   15] | d_loss: 0.1937 | g_loss: 4.6615
# Epoch [    8/   15] | d_loss: 0.3784 | g_loss: 3.9245
# Epoch [    8/   15] | d_loss: 0.3035 | g_loss: 4.7832
# Epoch [    8/   15] | d_loss: 0.3927 | g_loss: 3.1203
# Epoch [    8/   15] | d_loss: 0.2981 | g_loss: 5.0077
# Epoch [    8/   15] | d_loss: 0.1253 | g_loss: 3.4999
# Epoch [    8/   15] | d_loss: 0.8413 | g_loss: 3.4139
# Epoch [    8/   15] | d_loss: 0.2909 | g_loss: 8.1612
# Epoch [    8/   15] | d_loss: 0.1782 | g_loss: 2.3995
# Epoch [    8/   15] | d_loss: 0.3996 | g_loss: 4.0174
# Epoch [    8/   15] | d_loss: 1.1250 | g_loss: 2.2008
# Epoch [    8/   15] | d_loss: 0.0706 | g_loss: 5.4647
# Epoch [    8/   15] | d_loss: 0.1670 | g_loss: 3.1548
# Epoch [    8/   15] | d_loss: 0.2626 | g_loss: 4.6551
# Epoch [    8/   15] | d_loss: 0.2137 | g_loss: 4.5501
# Epoch [    8/   15] | d_loss: 0.0943 | g_loss: 3.8097
# Epoch [    8/   15] | d_loss: 0.0903 | g_loss: 6.8061
# Epoch [    8/   15] | d_loss: 0.2639 | g_loss: 3.8652
# Epoch [    8/   15] | d_loss: 1.2166 | g_loss: 4.5894
# Epoch [    8/   15] | d_loss: 0.6465 | g_loss: 1.7397
# Epoch [    8/   15] | d_loss: 0.0642 | g_loss: 3.1890
# Epoch [    8/   15] | d_loss: 0.3983 | g_loss: 3.5269
# Epoch [    8/   15] | d_loss: 0.5907 | g_loss: 3.1710
# Epoch [    8/   15] | d_loss: 0.1900 | g_loss: 5.3063
# Epoch [    8/   15] | d_loss: 0.2398 | g_loss: 7.3395
# Epoch [    8/   15] | d_loss: 0.2129 | g_loss: 2.7752
# Epoch [    8/   15] | d_loss: 0.0226 | g_loss: 5.5009
# Epoch [    8/   15] | d_loss: 0.2756 | g_loss: 3.5759
# Epoch [    8/   15] | d_loss: 0.0608 | g_loss: 5.4110
# Epoch [    8/   15] | d_loss: 0.0181 | g_loss: 5.4378
# Epoch [    8/   15] | d_loss: 0.7629 | g_loss: 6.0712
# Epoch [    8/   15] | d_loss: 0.2942 | g_loss: 8.2934
# Epoch [    8/   15] | d_loss: 0.2516 | g_loss: 3.6441
# Epoch [    8/   15] | d_loss: 0.4946 | g_loss: 5.9286
# Epoch [    8/   15] | d_loss: 0.7297 | g_loss: 3.0375
# Epoch [    8/   15] | d_loss: 0.1616 | g_loss: 5.9869
# Epoch [    8/   15] | d_loss: 0.4504 | g_loss: 4.1568
# Epoch [    8/   15] | d_loss: 0.1820 | g_loss: 5.7657
# Epoch [    8/   15] | d_loss: 0.1272 | g_loss: 3.5759
# Epoch [    8/   15] | d_loss: 0.1485 | g_loss: 10.3492
# Epoch [    8/   15] | d_loss: 0.1210 | g_loss: 6.0126
# Epoch [    8/   15] | d_loss: 0.5092 | g_loss: 4.3049
# Epoch [    8/   15] | d_loss: 1.1290 | g_loss: 3.4140
# Epoch [    8/   15] | d_loss: 0.7598 | g_loss: 3.5001
# Epoch [    8/   15] | d_loss: 0.2619 | g_loss: 3.2511
# Epoch [    8/   15] | d_loss: 0.2100 | g_loss: 5.8667
# Epoch [    8/   15] | d_loss: 0.2984 | g_loss: 5.4746
# Epoch [    8/   15] | d_loss: 0.5017 | g_loss: 4.2917
# Epoch [    8/   15] | d_loss: 0.1926 | g_loss: 7.3099
# Epoch [    9/   15] | d_loss: 0.6061 | g_loss: 2.8535
# Epoch [    9/   15] | d_loss: 0.2390 | g_loss: 3.7046
# Epoch [    9/   15] | d_loss: 0.2886 | g_loss: 5.3636
# Epoch [    9/   15] | d_loss: 0.2949 | g_loss: 5.8514
# Epoch [    9/   15] | d_loss: 0.0994 | g_loss: 5.9818
# Epoch [    9/   15] | d_loss: 0.1621 | g_loss: 2.5974
# Epoch [    9/   15] | d_loss: 0.0595 | g_loss: 4.7502
# Epoch [    9/   15] | d_loss: 0.2357 | g_loss: 7.2591
# Epoch [    9/   15] | d_loss: 0.0636 | g_loss: 4.8579
# Epoch [    9/   15] | d_loss: 0.5323 | g_loss: 3.2305
# Epoch [    9/   15] | d_loss: 0.0739 | g_loss: 5.5730
# Epoch [    9/   15] | d_loss: 0.0563 | g_loss: 7.7759
# Epoch [    9/   15] | d_loss: 0.0895 | g_loss: 6.0610
# Epoch [    9/   15] | d_loss: 0.2104 | g_loss: 4.3379
# Epoch [    9/   15] | d_loss: 0.1040 | g_loss: 5.4700
# Epoch [    9/   15] | d_loss: 0.3983 | g_loss: 4.0335
# Epoch [    9/   15] | d_loss: 0.1433 | g_loss: 4.1544
# Epoch [    9/   15] | d_loss: 0.0491 | g_loss: 4.8681
# Epoch [    9/   15] | d_loss: 1.1236 | g_loss: 8.7543
# Epoch [    9/   15] | d_loss: 0.0508 | g_loss: 5.0577
# Epoch [    9/   15] | d_loss: 0.3676 | g_loss: 2.3827
# Epoch [    9/   15] | d_loss: 0.0716 | g_loss: 6.5449
# Epoch [    9/   15] | d_loss: 0.2102 | g_loss: 3.7529
# Epoch [    9/   15] | d_loss: 0.2980 | g_loss: 2.8386
# Epoch [    9/   15] | d_loss: 0.3600 | g_loss: 0.7570
# Epoch [    9/   15] | d_loss: 0.1681 | g_loss: 5.0861
# Epoch [    9/   15] | d_loss: 1.1886 | g_loss: 3.0949
# Epoch [    9/   15] | d_loss: 1.5734 | g_loss: 2.3428
# Epoch [    9/   15] | d_loss: 0.7887 | g_loss: 2.5502
# Epoch [    9/   15] | d_loss: 0.1520 | g_loss: 6.8155
# Epoch [    9/   15] | d_loss: 0.1027 | g_loss: 4.1080
# Epoch [    9/   15] | d_loss: 0.2946 | g_loss: 5.0417
# Epoch [    9/   15] | d_loss: 0.9063 | g_loss: 7.2857
# Epoch [    9/   15] | d_loss: 0.6865 | g_loss: 3.6689
# Epoch [    9/   15] | d_loss: 0.5041 | g_loss: 4.1268
# Epoch [    9/   15] | d_loss: 0.2900 | g_loss: 2.9769
# Epoch [    9/   15] | d_loss: 0.2046 | g_loss: 3.5266
# Epoch [    9/   15] | d_loss: 0.1618 | g_loss: 4.4462
# Epoch [    9/   15] | d_loss: 0.6554 | g_loss: 3.8094
# Epoch [    9/   15] | d_loss: 0.7523 | g_loss: 5.6786
# Epoch [    9/   15] | d_loss: 0.2542 | g_loss: 4.7856
# Epoch [    9/   15] | d_loss: 1.1001 | g_loss: 7.6099
# Epoch [    9/   15] | d_loss: 0.1532 | g_loss: 5.0190
# Epoch [    9/   15] | d_loss: 0.1347 | g_loss: 5.6073
# Epoch [    9/   15] | d_loss: 0.9410 | g_loss: 3.9359
# Epoch [    9/   15] | d_loss: 0.1258 | g_loss: 5.2525
# Epoch [    9/   15] | d_loss: 0.1158 | g_loss: 4.0855
# Epoch [    9/   15] | d_loss: 0.9816 | g_loss: 2.7866
# Epoch [    9/   15] | d_loss: 0.6812 | g_loss: 5.6404
# Epoch [    9/   15] | d_loss: 0.1550 | g_loss: 3.4950
# Epoch [    9/   15] | d_loss: 0.2848 | g_loss: 3.4862
# Epoch [    9/   15] | d_loss: 2.3309 | g_loss: 3.3321
# Epoch [    9/   15] | d_loss: 0.1358 | g_loss: 4.3870
# Epoch [    9/   15] | d_loss: 0.1350 | g_loss: 5.5984
# Epoch [    9/   15] | d_loss: 0.2746 | g_loss: 5.2277
# Epoch [    9/   15] | d_loss: 0.1919 | g_loss: 2.9066
# Epoch [    9/   15] | d_loss: 0.9938 | g_loss: 3.0031
# Epoch [    9/   15] | d_loss: 0.0922 | g_loss: 5.4321
# Epoch [    9/   15] | d_loss: 0.2741 | g_loss: 2.7258
# Epoch [    9/   15] | d_loss: 0.4917 | g_loss: 5.2839
# Epoch [    9/   15] | d_loss: 0.0971 | g_loss: 5.6605
# Epoch [    9/   15] | d_loss: 0.5789 | g_loss: 5.5337
# Epoch [    9/   15] | d_loss: 0.2868 | g_loss: 8.8672
# Epoch [    9/   15] | d_loss: 0.2979 | g_loss: 3.8763
# Epoch [    9/   15] | d_loss: 0.2945 | g_loss: 8.1620
# Epoch [    9/   15] | d_loss: 0.1277 | g_loss: 4.3944
# Epoch [    9/   15] | d_loss: 0.0362 | g_loss: 5.3130
# Epoch [    9/   15] | d_loss: 0.1216 | g_loss: 6.9975
# Epoch [    9/   15] | d_loss: 0.0400 | g_loss: 5.7919
# Epoch [    9/   15] | d_loss: 0.2958 | g_loss: 4.7093
# Epoch [    9/   15] | d_loss: 0.2522 | g_loss: 4.3376
# Epoch [    9/   15] | d_loss: 0.5459 | g_loss: 5.7849
# Epoch [   10/   15] | d_loss: 0.6072 | g_loss: 3.2569
# Epoch [   10/   15] | d_loss: 2.2869 | g_loss: 6.8940
# Epoch [   10/   15] | d_loss: 0.2249 | g_loss: 2.5484
# Epoch [   10/   15] | d_loss: 0.0828 | g_loss: 4.4756
# Epoch [   10/   15] | d_loss: 0.7223 | g_loss: 1.4568
# Epoch [   10/   15] | d_loss: 0.1382 | g_loss: 4.9865
# Epoch [   10/   15] | d_loss: 0.0898 | g_loss: 4.8372
# Epoch [   10/   15] | d_loss: 0.0841 | g_loss: 5.5871
# Epoch [   10/   15] | d_loss: 0.5590 | g_loss: 2.4455
# Epoch [   10/   15] | d_loss: 0.3155 | g_loss: 5.7321
# Epoch [   10/   15] | d_loss: 0.2704 | g_loss: 4.8720
# Epoch [   10/   15] | d_loss: 0.2029 | g_loss: 4.3546
# Epoch [   10/   15] | d_loss: 0.1392 | g_loss: 3.5274
# Epoch [   10/   15] | d_loss: 0.0937 | g_loss: 5.3290
# Epoch [   10/   15] | d_loss: 0.0815 | g_loss: 3.6006
# Epoch [   10/   15] | d_loss: 0.0232 | g_loss: 7.4446
# Epoch [   10/   15] | d_loss: 0.1767 | g_loss: 2.3102
# Epoch [   10/   15] | d_loss: 0.2215 | g_loss: 2.8553
# Epoch [   10/   15] | d_loss: 0.1960 | g_loss: 4.5872
# Epoch [   10/   15] | d_loss: 0.0420 | g_loss: 4.1521
# Epoch [   10/   15] | d_loss: 0.0779 | g_loss: 6.9265
# Epoch [   10/   15] | d_loss: 0.3616 | g_loss: 3.7779
# Epoch [   10/   15] | d_loss: 0.5163 | g_loss: 5.1792
# Epoch [   10/   15] | d_loss: 0.0424 | g_loss: 5.8508
# Epoch [   10/   15] | d_loss: 0.1022 | g_loss: 4.3774
# Epoch [   10/   15] | d_loss: 0.9953 | g_loss: 8.9856
# Epoch [   10/   15] | d_loss: 0.0252 | g_loss: 7.8609
# Epoch [   10/   15] | d_loss: 0.2724 | g_loss: 6.7178
# Epoch [   10/   15] | d_loss: 0.0868 | g_loss: 2.6190
# Epoch [   10/   15] | d_loss: 0.0491 | g_loss: 7.4582
# Epoch [   10/   15] | d_loss: 0.4547 | g_loss: 1.7173
# Epoch [   10/   15] | d_loss: 0.1102 | g_loss: 3.9815
# Epoch [   10/   15] | d_loss: 0.4259 | g_loss: 4.2871
# Epoch [   10/   15] | d_loss: 0.1224 | g_loss: 7.2892
# Epoch [   10/   15] | d_loss: 0.4070 | g_loss: 4.8163
# Epoch [   10/   15] | d_loss: 0.4474 | g_loss: 3.0182
# Epoch [   10/   15] | d_loss: 0.6279 | g_loss: 7.0946
# Epoch [   10/   15] | d_loss: 0.1319 | g_loss: 3.6432
# Epoch [   10/   15] | d_loss: 1.0338 | g_loss: 11.7614
# Epoch [   10/   15] | d_loss: 0.3333 | g_loss: 4.5444
# Epoch [   10/   15] | d_loss: 0.0038 | g_loss: 5.9262
# Epoch [   10/   15] | d_loss: 0.1445 | g_loss: 3.5676
# Epoch [   10/   15] | d_loss: 0.0169 | g_loss: 5.2977
# Epoch [   10/   15] | d_loss: 0.2424 | g_loss: 1.8820
# Epoch [   10/   15] | d_loss: 0.3272 | g_loss: 4.1471
# Epoch [   10/   15] | d_loss: 0.4466 | g_loss: 4.0790
# Epoch [   10/   15] | d_loss: 0.7816 | g_loss: 6.8517
# Epoch [   10/   15] | d_loss: 0.2184 | g_loss: 4.7477
# Epoch [   10/   15] | d_loss: 0.1039 | g_loss: 9.3250
# Epoch [   10/   15] | d_loss: 3.1931 | g_loss: 3.3569
# Epoch [   10/   15] | d_loss: 0.0147 | g_loss: 4.9163
# Epoch [   10/   15] | d_loss: 0.2005 | g_loss: 3.5872
# Epoch [   10/   15] | d_loss: 0.0651 | g_loss: 8.2651
# Epoch [   10/   15] | d_loss: 0.4728 | g_loss: 5.6981
# Epoch [   10/   15] | d_loss: 0.1631 | g_loss: 4.6823
# Epoch [   10/   15] | d_loss: 1.1303 | g_loss: 2.5335
# Epoch [   10/   15] | d_loss: 0.4220 | g_loss: 7.1124
# Epoch [   10/   15] | d_loss: 0.0843 | g_loss: 2.3782
# Epoch [   10/   15] | d_loss: 0.0218 | g_loss: 4.3042
# Epoch [   10/   15] | d_loss: 0.0861 | g_loss: 5.3285
# Epoch [   10/   15] | d_loss: 0.1124 | g_loss: 5.8083
# Epoch [   10/   15] | d_loss: 0.3277 | g_loss: 3.5726
# Epoch [   10/   15] | d_loss: 0.0331 | g_loss: 5.2441
# Epoch [   10/   15] | d_loss: 0.4604 | g_loss: 6.0709
# Epoch [   10/   15] | d_loss: 0.0125 | g_loss: 5.4062
# Epoch [   10/   15] | d_loss: 0.1973 | g_loss: 5.1198
# Epoch [   10/   15] | d_loss: 0.0992 | g_loss: 5.6722
# Epoch [   10/   15] | d_loss: 0.2245 | g_loss: 6.1610
# Epoch [   10/   15] | d_loss: 0.8544 | g_loss: 7.4338
# Epoch [   10/   15] | d_loss: 0.5595 | g_loss: 3.2390
# Epoch [   10/   15] | d_loss: 0.2402 | g_loss: 3.4218
# Epoch [   10/   15] | d_loss: 0.0683 | g_loss: 3.6265
# Epoch [   11/   15] | d_loss: 2.9367 | g_loss: 8.9326
# Epoch [   11/   15] | d_loss: 0.1979 | g_loss: 4.7143
# Epoch [   11/   15] | d_loss: 0.2684 | g_loss: 1.3920
# Epoch [   11/   15] | d_loss: 0.1916 | g_loss: 6.4218
# Epoch [   11/   15] | d_loss: 0.6345 | g_loss: 5.1877
# Epoch [   11/   15] | d_loss: 0.0343 | g_loss: 6.0007
# Epoch [   11/   15] | d_loss: 0.8861 | g_loss: 4.8703
# Epoch [   11/   15] | d_loss: 0.7282 | g_loss: 4.3975
# Epoch [   11/   15] | d_loss: 0.2268 | g_loss: 4.5729
# Epoch [   11/   15] | d_loss: 0.7566 | g_loss: 8.1281
# Epoch [   11/   15] | d_loss: 0.8196 | g_loss: 3.2872
# Epoch [   11/   15] | d_loss: 0.0151 | g_loss: 9.7612
# Epoch [   11/   15] | d_loss: 0.1770 | g_loss: 2.7590
# Epoch [   11/   15] | d_loss: 0.3630 | g_loss: 5.3676
# Epoch [   11/   15] | d_loss: 0.8483 | g_loss: 6.1794
# Epoch [   11/   15] | d_loss: 0.3079 | g_loss: 4.0883
# Epoch [   11/   15] | d_loss: 0.0181 | g_loss: 7.0854
# Epoch [   11/   15] | d_loss: 0.1550 | g_loss: 4.6657
# Epoch [   11/   15] | d_loss: 0.1489 | g_loss: 6.9087
# Epoch [   11/   15] | d_loss: 0.2944 | g_loss: 4.5017
# Epoch [   11/   15] | d_loss: 0.0789 | g_loss: 4.9573
# Epoch [   11/   15] | d_loss: 0.2513 | g_loss: 8.5338
# Epoch [   11/   15] | d_loss: 0.1341 | g_loss: 3.2576
# Epoch [   11/   15] | d_loss: 0.2819 | g_loss: 4.4329
# Epoch [   11/   15] | d_loss: 0.7840 | g_loss: 4.2197
# Epoch [   11/   15] | d_loss: 0.3030 | g_loss: 3.9678
# Epoch [   11/   15] | d_loss: 0.0348 | g_loss: 8.8553
# Epoch [   11/   15] | d_loss: 0.4658 | g_loss: 5.5489
# Epoch [   11/   15] | d_loss: 0.3858 | g_loss: 4.6984
# Epoch [   11/   15] | d_loss: 0.1679 | g_loss: 4.3128
# Epoch [   11/   15] | d_loss: 0.1143 | g_loss: 5.9480
# Epoch [   11/   15] | d_loss: 0.0597 | g_loss: 5.4823
# Epoch [   11/   15] | d_loss: 0.7202 | g_loss: 3.6423
# Epoch [   11/   15] | d_loss: 0.2918 | g_loss: 7.4390
# Epoch [   11/   15] | d_loss: 0.0229 | g_loss: 5.0951
# Epoch [   11/   15] | d_loss: 0.0846 | g_loss: 9.7803
# Epoch [   11/   15] | d_loss: 0.1148 | g_loss: 5.0130
# Epoch [   11/   15] | d_loss: 0.2000 | g_loss: 1.0787
# Epoch [   11/   15] | d_loss: 0.1244 | g_loss: 4.9219
# Epoch [   11/   15] | d_loss: 0.0848 | g_loss: 5.6221
# Epoch [   11/   15] | d_loss: 0.2057 | g_loss: 4.3892
# Epoch [   11/   15] | d_loss: 0.1873 | g_loss: 6.8838
# Epoch [   11/   15] | d_loss: 0.0908 | g_loss: 4.8659
# Epoch [   11/   15] | d_loss: 0.1466 | g_loss: 3.2064
# Epoch [   11/   15] | d_loss: 0.4179 | g_loss: 5.7074
# Epoch [   11/   15] | d_loss: 1.4384 | g_loss: 11.5967
# Epoch [   11/   15] | d_loss: 0.0438 | g_loss: 6.4992
# Epoch [   11/   15] | d_loss: 0.4043 | g_loss: 6.3719
# Epoch [   11/   15] | d_loss: 0.2890 | g_loss: 2.9819
# Epoch [   11/   15] | d_loss: 0.1481 | g_loss: 3.0076
# Epoch [   11/   15] | d_loss: 0.0351 | g_loss: 5.3137
# Epoch [   11/   15] | d_loss: 0.0540 | g_loss: 4.8741
# Epoch [   11/   15] | d_loss: 0.5309 | g_loss: 4.5616
# Epoch [   11/   15] | d_loss: 0.0529 | g_loss: 2.1427
# Epoch [   11/   15] | d_loss: 0.1635 | g_loss: 3.8419
# Epoch [   11/   15] | d_loss: 0.0458 | g_loss: 6.9505
# Epoch [   11/   15] | d_loss: 0.1995 | g_loss: 7.1876
# Epoch [   11/   15] | d_loss: 0.0739 | g_loss: 7.5045
# Epoch [   11/   15] | d_loss: 0.0113 | g_loss: 8.9555
# Epoch [   11/   15] | d_loss: 0.0226 | g_loss: 4.2259
# Epoch [   11/   15] | d_loss: 0.1550 | g_loss: 3.3044
# Epoch [   11/   15] | d_loss: 0.0906 | g_loss: 9.9282
# Epoch [   11/   15] | d_loss: 0.3352 | g_loss: 2.0324
# Epoch [   11/   15] | d_loss: 0.0759 | g_loss: 6.4086
# Epoch [   11/   15] | d_loss: 0.1719 | g_loss: 3.3959
# Epoch [   11/   15] | d_loss: 0.2397 | g_loss: 2.3616
# Epoch [   11/   15] | d_loss: 0.8429 | g_loss: 3.0197
# Epoch [   11/   15] | d_loss: 0.2658 | g_loss: 8.3894
# Epoch [   11/   15] | d_loss: 0.1011 | g_loss: 4.1773
# Epoch [   11/   15] | d_loss: 1.3084 | g_loss: 1.7114
# Epoch [   11/   15] | d_loss: 0.1141 | g_loss: 4.3773
# Epoch [   11/   15] | d_loss: 0.0304 | g_loss: 5.8373
# Epoch [   12/   15] | d_loss: 0.4582 | g_loss: 2.7200
# Epoch [   12/   15] | d_loss: 0.6182 | g_loss: 6.5824
# Epoch [   12/   15] | d_loss: 0.1386 | g_loss: 5.3124
# Epoch [   12/   15] | d_loss: 2.2813 | g_loss: 10.5257
# Epoch [   12/   15] | d_loss: 0.0705 | g_loss: 7.5113
# Epoch [   12/   15] | d_loss: 0.1889 | g_loss: 4.9403
# Epoch [   12/   15] | d_loss: 0.0682 | g_loss: 5.3179
# Epoch [   12/   15] | d_loss: 0.0956 | g_loss: 4.9385
# Epoch [   12/   15] | d_loss: 0.1991 | g_loss: 3.9559
# Epoch [   12/   15] | d_loss: 0.5174 | g_loss: 7.5469
# Epoch [   12/   15] | d_loss: 0.4920 | g_loss: 7.7541
# Epoch [   12/   15] | d_loss: 0.1824 | g_loss: 8.5855
# Epoch [   12/   15] | d_loss: 0.2662 | g_loss: 5.2964
# Epoch [   12/   15] | d_loss: 0.4169 | g_loss: 7.4032
# Epoch [   12/   15] | d_loss: 0.2568 | g_loss: 5.5649
# Epoch [   12/   15] | d_loss: 0.0566 | g_loss: 4.9047
# Epoch [   12/   15] | d_loss: 0.0891 | g_loss: 4.7162
# Epoch [   12/   15] | d_loss: 0.0792 | g_loss: 4.8726
# Epoch [   12/   15] | d_loss: 0.0684 | g_loss: 3.9898
# Epoch [   12/   15] | d_loss: 0.1403 | g_loss: 3.9095
# Epoch [   12/   15] | d_loss: 0.0515 | g_loss: 4.1660
# Epoch [   12/   15] | d_loss: 0.7960 | g_loss: 2.3121
# Epoch [   12/   15] | d_loss: 0.1585 | g_loss: 5.3398
# Epoch [   12/   15] | d_loss: 0.2483 | g_loss: 2.2346
# Epoch [   12/   15] | d_loss: 0.1787 | g_loss: 5.1585
# Epoch [   12/   15] | d_loss: 0.0387 | g_loss: 6.4482
# Epoch [   12/   15] | d_loss: 0.1749 | g_loss: 7.3940
# Epoch [   12/   15] | d_loss: 0.9806 | g_loss: 4.3731
# Epoch [   12/   15] | d_loss: 0.6454 | g_loss: 1.9377
# Epoch [   12/   15] | d_loss: 0.0856 | g_loss: 7.5309
# Epoch [   12/   15] | d_loss: 0.6207 | g_loss: 3.1815
# Epoch [   12/   15] | d_loss: 0.1595 | g_loss: 3.0915
# Epoch [   12/   15] | d_loss: 0.0185 | g_loss: 4.9412
# Epoch [   12/   15] | d_loss: 0.0807 | g_loss: 5.2857
# Epoch [   12/   15] | d_loss: 0.5257 | g_loss: 3.0448
# Epoch [   12/   15] | d_loss: 0.0505 | g_loss: 8.2583
# Epoch [   12/   15] | d_loss: 0.3843 | g_loss: 6.0328
# Epoch [   12/   15] | d_loss: 0.0283 | g_loss: 5.1425
# Epoch [   12/   15] | d_loss: 0.1519 | g_loss: 3.8183
# Epoch [   12/   15] | d_loss: 0.0748 | g_loss: 5.3867
# Epoch [   12/   15] | d_loss: 0.0591 | g_loss: 7.2751
# Epoch [   12/   15] | d_loss: 0.6431 | g_loss: 4.0053
# Epoch [   12/   15] | d_loss: 0.6887 | g_loss: 11.1289
# Epoch [   12/   15] | d_loss: 0.0280 | g_loss: 7.3478
# Epoch [   12/   15] | d_loss: 0.3487 | g_loss: 4.3471
# Epoch [   12/   15] | d_loss: 0.2719 | g_loss: 7.0723
# Epoch [   12/   15] | d_loss: 0.1889 | g_loss: 3.9228
# Epoch [   12/   15] | d_loss: 0.1756 | g_loss: 6.3259
# Epoch [   12/   15] | d_loss: 0.2450 | g_loss: 7.7115
# Epoch [   12/   15] | d_loss: 0.0704 | g_loss: 3.1776
# Epoch [   12/   15] | d_loss: 0.1969 | g_loss: 6.8932
# Epoch [   12/   15] | d_loss: 0.0782 | g_loss: 4.8123
# Epoch [   12/   15] | d_loss: 0.1704 | g_loss: 4.7119
# Epoch [   12/   15] | d_loss: 0.0134 | g_loss: 6.8957
# Epoch [   12/   15] | d_loss: 0.4433 | g_loss: 3.6300
# Epoch [   12/   15] | d_loss: 0.0418 | g_loss: 2.8698
# Epoch [   12/   15] | d_loss: 0.1965 | g_loss: 4.2859
# Epoch [   12/   15] | d_loss: 0.6441 | g_loss: 7.8466
# Epoch [   12/   15] | d_loss: 0.0777 | g_loss: 9.2532
# Epoch [   12/   15] | d_loss: 0.7590 | g_loss: 5.8397
# Epoch [   12/   15] | d_loss: 0.0344 | g_loss: 5.6157
# Epoch [   12/   15] | d_loss: 0.1182 | g_loss: 7.6648
# Epoch [   12/   15] | d_loss: 0.1912 | g_loss: 7.3349
# Epoch [   12/   15] | d_loss: 0.1997 | g_loss: 4.2541
# Epoch [   12/   15] | d_loss: 0.4063 | g_loss: 3.7174
# Epoch [   12/   15] | d_loss: 1.0383 | g_loss: 6.9839
# Epoch [   12/   15] | d_loss: 0.0772 | g_loss: 4.4710
# Epoch [   12/   15] | d_loss: 0.0811 | g_loss: 4.5384
# Epoch [   12/   15] | d_loss: 0.0507 | g_loss: 5.9506
# Epoch [   12/   15] | d_loss: 0.2403 | g_loss: 2.3285
# Epoch [   12/   15] | d_loss: 0.4447 | g_loss: 4.4629
# Epoch [   12/   15] | d_loss: 0.9418 | g_loss: 4.2141
# Epoch [   13/   15] | d_loss: 0.2244 | g_loss: 8.1141
# Epoch [   13/   15] | d_loss: 0.5544 | g_loss: 5.6742
# Epoch [   13/   15] | d_loss: 0.1605 | g_loss: 5.9064
# Epoch [   13/   15] | d_loss: 0.3060 | g_loss: 6.2549
# Epoch [   13/   15] | d_loss: 0.0895 | g_loss: 5.6400
# Epoch [   13/   15] | d_loss: 0.0761 | g_loss: 5.1080
# Epoch [   13/   15] | d_loss: 0.9865 | g_loss: 5.7595
# Epoch [   13/   15] | d_loss: 0.0452 | g_loss: 5.3034
# Epoch [   13/   15] | d_loss: 0.3015 | g_loss: 3.0478
# Epoch [   13/   15] | d_loss: 0.2362 | g_loss: 7.1694
# Epoch [   13/   15] | d_loss: 0.1643 | g_loss: 8.2392
# Epoch [   13/   15] | d_loss: 0.1290 | g_loss: 3.3506
# Epoch [   13/   15] | d_loss: 0.7471 | g_loss: 4.0386
# Epoch [   13/   15] | d_loss: 0.4472 | g_loss: 2.3071
# Epoch [   13/   15] | d_loss: 0.6817 | g_loss: 1.6964
# Epoch [   13/   15] | d_loss: 0.3012 | g_loss: 3.6957
# Epoch [   13/   15] | d_loss: 0.0421 | g_loss: 8.5302
# Epoch [   13/   15] | d_loss: 0.0978 | g_loss: 4.4244
# Epoch [   13/   15] | d_loss: 0.4279 | g_loss: 5.0900
# Epoch [   13/   15] | d_loss: 0.1715 | g_loss: 4.7824
# Epoch [   13/   15] | d_loss: 0.0261 | g_loss: 7.5112
# Epoch [   13/   15] | d_loss: 0.1324 | g_loss: 5.6372
# Epoch [   13/   15] | d_loss: 0.3544 | g_loss: 5.2417
# Epoch [   13/   15] | d_loss: 0.1179 | g_loss: 5.5297
# Epoch [   13/   15] | d_loss: 0.0270 | g_loss: 6.2555
# Epoch [   13/   15] | d_loss: 0.5516 | g_loss: 5.5497
# Epoch [   13/   15] | d_loss: 0.2355 | g_loss: 5.8016
# Epoch [   13/   15] | d_loss: 0.0405 | g_loss: 4.6084
# Epoch [   13/   15] | d_loss: 0.2355 | g_loss: 3.7086
# Epoch [   13/   15] | d_loss: 0.2228 | g_loss: 4.5648
# Epoch [   13/   15] | d_loss: 0.8918 | g_loss: 4.1492
# Epoch [   13/   15] | d_loss: 0.4303 | g_loss: 2.7749
# Epoch [   13/   15] | d_loss: 0.2189 | g_loss: 8.0166
# Epoch [   13/   15] | d_loss: 0.2716 | g_loss: 2.5005
# Epoch [   13/   15] | d_loss: 0.2992 | g_loss: 2.8893
# Epoch [   13/   15] | d_loss: 0.2025 | g_loss: 6.5462
# Epoch [   13/   15] | d_loss: 0.6569 | g_loss: 2.7630
# Epoch [   13/   15] | d_loss: 0.0805 | g_loss: 3.3286
# Epoch [   13/   15] | d_loss: 0.1661 | g_loss: 5.1392
# Epoch [   13/   15] | d_loss: 0.2088 | g_loss: 2.6166
# Epoch [   13/   15] | d_loss: 0.0384 | g_loss: 6.9744
# Epoch [   13/   15] | d_loss: 0.0142 | g_loss: 7.1545
# Epoch [   13/   15] | d_loss: 0.3312 | g_loss: 2.8254
# Epoch [   13/   15] | d_loss: 0.1994 | g_loss: 2.6849
# Epoch [   13/   15] | d_loss: 0.0989 | g_loss: 7.0896
# Epoch [   13/   15] | d_loss: 0.1423 | g_loss: 6.4463
# Epoch [   13/   15] | d_loss: 0.2607 | g_loss: 3.8843
# Epoch [   13/   15] | d_loss: 0.1203 | g_loss: 6.6933
# Epoch [   13/   15] | d_loss: 0.2826 | g_loss: 6.6713
# Epoch [   13/   15] | d_loss: 0.1431 | g_loss: 3.2475
# Epoch [   13/   15] | d_loss: 0.1503 | g_loss: 4.9761
# Epoch [   13/   15] | d_loss: 0.7522 | g_loss: 3.8222
# Epoch [   13/   15] | d_loss: 0.2636 | g_loss: 4.1042
# Epoch [   13/   15] | d_loss: 0.0297 | g_loss: 5.0573
# Epoch [   13/   15] | d_loss: 0.0661 | g_loss: 3.1205
# Epoch [   13/   15] | d_loss: 0.1172 | g_loss: 2.2742
# Epoch [   13/   15] | d_loss: 0.3142 | g_loss: 2.2391
# Epoch [   13/   15] | d_loss: 0.2219 | g_loss: 6.5326
# Epoch [   13/   15] | d_loss: 0.4836 | g_loss: 5.9648
# Epoch [   13/   15] | d_loss: 0.0631 | g_loss: 3.5473
# Epoch [   13/   15] | d_loss: 0.0863 | g_loss: 6.6976
# Epoch [   13/   15] | d_loss: 0.1279 | g_loss: 6.2175
# Epoch [   13/   15] | d_loss: 0.4955 | g_loss: 2.2859
# Epoch [   13/   15] | d_loss: 0.2507 | g_loss: 5.3618
# Epoch [   13/   15] | d_loss: 0.2111 | g_loss: 7.2229
# Epoch [   13/   15] | d_loss: 0.3340 | g_loss: 8.3684
# Epoch [   13/   15] | d_loss: 0.3120 | g_loss: 7.5951
# Epoch [   13/   15] | d_loss: 0.5268 | g_loss: 2.6324
# Epoch [   13/   15] | d_loss: 0.0398 | g_loss: 5.7470
# Epoch [   13/   15] | d_loss: 0.1783 | g_loss: 6.1350
# Epoch [   13/   15] | d_loss: 0.5726 | g_loss: 3.1881
# Epoch [   13/   15] | d_loss: 1.6107 | g_loss: 10.1333
# Epoch [   14/   15] | d_loss: 0.1939 | g_loss: 4.8774
# Epoch [   14/   15] | d_loss: 0.0198 | g_loss: 6.0757
# Epoch [   14/   15] | d_loss: 0.6444 | g_loss: 2.8055
# Epoch [   14/   15] | d_loss: 2.4296 | g_loss: 5.6042
# Epoch [   14/   15] | d_loss: 0.0265 | g_loss: 4.9715
# Epoch [   14/   15] | d_loss: 0.0715 | g_loss: 7.5918
# Epoch [   14/   15] | d_loss: 0.0139 | g_loss: 8.4463
# Epoch [   14/   15] | d_loss: 0.1101 | g_loss: 3.9972
# Epoch [   14/   15] | d_loss: 0.0709 | g_loss: 3.8702
# Epoch [   14/   15] | d_loss: 0.0804 | g_loss: 4.0517
# Epoch [   14/   15] | d_loss: 0.2542 | g_loss: 3.5093
# Epoch [   14/   15] | d_loss: 0.5912 | g_loss: 7.6101
# Epoch [   14/   15] | d_loss: 0.2061 | g_loss: 5.6114
# Epoch [   14/   15] | d_loss: 0.5597 | g_loss: 4.7745
# Epoch [   14/   15] | d_loss: 0.4524 | g_loss: 2.2731
# Epoch [   14/   15] | d_loss: 0.5658 | g_loss: 5.7140
# Epoch [   14/   15] | d_loss: 0.0984 | g_loss: 5.7994
# Epoch [   14/   15] | d_loss: 0.0873 | g_loss: 5.3192
# Epoch [   14/   15] | d_loss: 0.4035 | g_loss: 4.7097
# Epoch [   14/   15] | d_loss: 0.0721 | g_loss: 7.1047
# Epoch [   14/   15] | d_loss: 0.3486 | g_loss: 7.3204
# Epoch [   14/   15] | d_loss: 0.4840 | g_loss: 4.5203
# Epoch [   14/   15] | d_loss: 0.1828 | g_loss: 6.8568
# Epoch [   14/   15] | d_loss: 0.7050 | g_loss: 5.3716
# Epoch [   14/   15] | d_loss: 0.4072 | g_loss: 8.9950
# Epoch [   14/   15] | d_loss: 0.0293 | g_loss: 2.0399
# Epoch [   14/   15] | d_loss: 0.3109 | g_loss: 6.6584
# Epoch [   14/   15] | d_loss: 0.3726 | g_loss: 6.6204
# Epoch [   14/   15] | d_loss: 0.5431 | g_loss: 6.0381
# Epoch [   14/   15] | d_loss: 1.1240 | g_loss: 7.2891
# Epoch [   14/   15] | d_loss: 0.1687 | g_loss: 4.1551
# Epoch [   14/   15] | d_loss: 0.1503 | g_loss: 6.8188
# Epoch [   14/   15] | d_loss: 0.9497 | g_loss: 4.1026
# Epoch [   14/   15] | d_loss: 1.6375 | g_loss: 9.0018
# Epoch [   14/   15] | d_loss: 0.0311 | g_loss: 5.3534
# Epoch [   14/   15] | d_loss: 0.8445 | g_loss: 5.6291
# Epoch [   14/   15] | d_loss: 0.2835 | g_loss: 3.6683
# Epoch [   14/   15] | d_loss: 0.2567 | g_loss: 9.2787
# Epoch [   14/   15] | d_loss: 0.3525 | g_loss: 6.9220
# Epoch [   14/   15] | d_loss: 0.0211 | g_loss: 5.6429
# Epoch [   14/   15] | d_loss: 0.3161 | g_loss: 6.3947
# Epoch [   14/   15] | d_loss: 0.1822 | g_loss: 5.8115
# Epoch [   14/   15] | d_loss: 0.0101 | g_loss: 5.0136
# Epoch [   14/   15] | d_loss: 0.2181 | g_loss: 7.1349
# Epoch [   14/   15] | d_loss: 0.5122 | g_loss: 5.8069
# Epoch [   14/   15] | d_loss: 0.1476 | g_loss: 5.2667
# Epoch [   14/   15] | d_loss: 1.5019 | g_loss: 8.0183
# Epoch [   14/   15] | d_loss: 0.0304 | g_loss: 5.6947
# Epoch [   14/   15] | d_loss: 0.0443 | g_loss: 5.0428
# Epoch [   14/   15] | d_loss: 0.3181 | g_loss: 3.5784
# Epoch [   14/   15] | d_loss: 0.2390 | g_loss: 1.4856
# Epoch [   14/   15] | d_loss: 0.3891 | g_loss: 7.0380
# Epoch [   14/   15] | d_loss: 0.3656 | g_loss: 4.5208
# Epoch [   14/   15] | d_loss: 0.1284 | g_loss: 2.5777
# Epoch [   14/   15] | d_loss: 0.0637 | g_loss: 4.7174
# Epoch [   14/   15] | d_loss: 0.2008 | g_loss: 8.0353
# Epoch [   14/   15] | d_loss: 0.1686 | g_loss: 5.7649
# Epoch [   14/   15] | d_loss: 0.0051 | g_loss: 3.1498
# Epoch [   14/   15] | d_loss: 0.6257 | g_loss: 3.5993
# Epoch [   14/   15] | d_loss: 0.1414 | g_loss: 6.5371
# Epoch [   14/   15] | d_loss: 0.0142 | g_loss: 5.3950
# Epoch [   14/   15] | d_loss: 0.2300 | g_loss: 4.3967
# Epoch [   14/   15] | d_loss: 0.0686 | g_loss: 2.4881
# Epoch [   14/   15] | d_loss: 0.1621 | g_loss: 4.6725
# Epoch [   14/   15] | d_loss: 0.4588 | g_loss: 4.3063
# Epoch [   14/   15] | d_loss: 0.8185 | g_loss: 4.0140
# Epoch [   14/   15] | d_loss: 0.0615 | g_loss: 4.8775
# Epoch [   14/   15] | d_loss: 0.1042 | g_loss: 8.6040
# Epoch [   14/   15] | d_loss: 0.0407 | g_loss: 5.6575
# Epoch [   14/   15] | d_loss: 0.0673 | g_loss: 5.3485
# Epoch [   14/   15] | d_loss: 0.0054 | g_loss: 6.6513
# Epoch [   14/   15] | d_loss: 0.2817 | g_loss: 2.9302
# Epoch [   15/   15] | d_loss: 2.9163 | g_loss: 10.0043
# Epoch [   15/   15] | d_loss: 0.2862 | g_loss: 4.8377
# Epoch [   15/   15] | d_loss: 0.1514 | g_loss: 4.8066
# Epoch [   15/   15] | d_loss: 0.5920 | g_loss: 4.2063
# Epoch [   15/   15] | d_loss: 0.8072 | g_loss: 4.8064
# Epoch [   15/   15] | d_loss: 1.2883 | g_loss: 7.3503
# Epoch [   15/   15] | d_loss: 0.1481 | g_loss: 3.1220
# Epoch [   15/   15] | d_loss: 0.3221 | g_loss: 7.9106
# Epoch [   15/   15] | d_loss: 0.4207 | g_loss: 6.0426
# Epoch [   15/   15] | d_loss: 0.1166 | g_loss: 4.0584
# Epoch [   15/   15] | d_loss: 0.1347 | g_loss: 6.1540
# Epoch [   15/   15] | d_loss: 0.0165 | g_loss: 7.2395
# Epoch [   15/   15] | d_loss: 0.2752 | g_loss: 4.2137
# Epoch [   15/   15] | d_loss: 0.2154 | g_loss: 5.2520
# Epoch [   15/   15] | d_loss: 0.1874 | g_loss: 2.8750
# Epoch [   15/   15] | d_loss: 0.0814 | g_loss: 4.5815
# Epoch [   15/   15] | d_loss: 0.0704 | g_loss: 9.9785
# Epoch [   15/   15] | d_loss: 0.5343 | g_loss: 7.7160
# Epoch [   15/   15] | d_loss: 0.0491 | g_loss: 6.1466
# Epoch [   15/   15] | d_loss: 0.1580 | g_loss: 6.7563
# Epoch [   15/   15] | d_loss: 0.0032 | g_loss: 6.1176
# Epoch [   15/   15] | d_loss: 0.4569 | g_loss: 5.3184
# Epoch [   15/   15] | d_loss: 0.3902 | g_loss: 5.9601
# Epoch [   15/   15] | d_loss: 1.2338 | g_loss: 3.2148
# Epoch [   15/   15] | d_loss: 0.6739 | g_loss: 4.6156
# Epoch [   15/   15] | d_loss: 0.1655 | g_loss: 5.1299
# Epoch [   15/   15] | d_loss: 0.1636 | g_loss: 6.1863
# Epoch [   15/   15] | d_loss: 0.1757 | g_loss: 1.8490
# Epoch [   15/   15] | d_loss: 0.3659 | g_loss: 6.7482
# Epoch [   15/   15] | d_loss: 0.4910 | g_loss: 4.2069
# Epoch [   15/   15] | d_loss: 0.7820 | g_loss: 7.0184
# Epoch [   15/   15] | d_loss: 0.5289 | g_loss: 5.9863
# Epoch [   15/   15] | d_loss: 0.1512 | g_loss: 6.6574
# Epoch [   15/   15] | d_loss: 0.0092 | g_loss: 5.5566
# Epoch [   15/   15] | d_loss: 0.0994 | g_loss: 7.3062
# Epoch [   15/   15] | d_loss: 0.1455 | g_loss: 3.0641
# Epoch [   15/   15] | d_loss: 0.0596 | g_loss: 6.2069
# Epoch [   15/   15] | d_loss: 0.0410 | g_loss: 7.6734
# Epoch [   15/   15] | d_loss: 0.5760 | g_loss: 3.9360
# Epoch [   15/   15] | d_loss: 0.2170 | g_loss: 6.0148
# Epoch [   15/   15] | d_loss: 0.6580 | g_loss: 4.5004
# Epoch [   15/   15] | d_loss: 0.0214 | g_loss: 8.6366
# Epoch [   15/   15] | d_loss: 0.2550 | g_loss: 4.6200
# Epoch [   15/   15] | d_loss: 0.1665 | g_loss: 7.2197
# Epoch [   15/   15] | d_loss: 0.1882 | g_loss: 4.2763
# Epoch [   15/   15] | d_loss: 0.2148 | g_loss: 6.2747
# Epoch [   15/   15] | d_loss: 0.2061 | g_loss: 8.0923
# Epoch [   15/   15] | d_loss: 0.1073 | g_loss: 7.5982
# Epoch [   15/   15] | d_loss: 0.6405 | g_loss: 6.0778
# Epoch [   15/   15] | d_loss: 0.1560 | g_loss: 5.6919
# Epoch [   15/   15] | d_loss: 0.1966 | g_loss: 5.5414
# Epoch [   15/   15] | d_loss: 0.0976 | g_loss: 8.1138
# Epoch [   15/   15] | d_loss: 0.0175 | g_loss: 7.8517
# Epoch [   15/   15] | d_loss: 0.7288 | g_loss: 3.1013
# Epoch [   15/   15] | d_loss: 0.9607 | g_loss: 6.5077
# Epoch [   15/   15] | d_loss: 0.5543 | g_loss: 4.3071
# Epoch [   15/   15] | d_loss: 0.2052 | g_loss: 3.8211
# Epoch [   15/   15] | d_loss: 0.2058 | g_loss: 6.4863
# Epoch [   15/   15] | d_loss: 0.6914 | g_loss: 2.4116
# Epoch [   15/   15] | d_loss: 0.2104 | g_loss: 3.2536
# Epoch [   15/   15] | d_loss: 0.2933 | g_loss: 5.1687
# Epoch [   15/   15] | d_loss: 0.1150 | g_loss: 3.6055
# Epoch [   15/   15] | d_loss: 0.5051 | g_loss: 7.6852
# Epoch [   15/   15] | d_loss: 0.1741 | g_loss: 6.9730
# Epoch [   15/   15] | d_loss: 0.3025 | g_loss: 5.5159
# Epoch [   15/   15] | d_loss: 0.1219 | g_loss: 7.5901
# Epoch [   15/   15] | d_loss: 0.5631 | g_loss: 4.3940
# Epoch [   15/   15] | d_loss: 0.0298 | g_loss: 5.7182
# Epoch [   15/   15] | d_loss: 0.9669 | g_loss: 0.7363
# Epoch [   15/   15] | d_loss: 0.4900 | g_loss: 2.9540
# Epoch [   15/   15] | d_loss: 0.3116 | g_loss: 4.0151
# Epoch [   15/   15] | d_loss: 0.1367 | g_loss: 4.0116

# %% [markdown]
# ## Training loss
#
# Plot the training losses for the generator and discriminator, recorded after each epoch.

# %%
fig, ax = plt.subplots()
losses = np.array(losses)
plt.plot(losses.T[0], label='Discriminator', alpha=0.5)
plt.plot(losses.T[1], label='Generator', alpha=0.5)
plt.title("Training Losses")
plt.legend()

# %% [markdown]
# ## Generator samples from training
#
# View samples of images from the generator, and answer a question about the strengths and weaknesses of your trained models.

# %%
# helper function for viewing a list of passed in sample images
def view_samples(epoch, samples):
    fig, axes = plt.subplots(figsize=(16,4), nrows=2, ncols=8, sharey=True, sharex=True)
    for ax, img in zip(axes.flatten(), samples[epoch]):
        img = img.detach().cpu().numpy()
        img = np.transpose(img, (1, 2, 0))
        img = ((img + 1)*255 / (2)).astype(np.uint8)
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        im = ax.imshow(img.reshape((32,32,3)))

# %%
# Load samples from generator, taken while training
with open('train_samples.pkl', 'rb') as f:
    samples = pkl.load(f)

# %%
_ = view_samples(-1, samples)

# %% [markdown]
# ### Question: What do you notice about your generated samples and how might you improve this model?
# When you answer this question, consider the following factors:
# * The dataset is biased; it is made of "celebrity" faces that are mostly white
# * Model size; larger models have the opportunity to learn more features in a data feature space
# * Optimization strategy; optimizers and number of epochs affect your final result

# %% [markdown]
# **Answer:** Getting dataset with larger number of samples with more features can help us in generating better faces, model size can also be iimproved by considering larger size images hence after we can define even more dense generators and discriminator models
# We can train for larger number of epochs i.e, for 250 or 500 epochs to get better performance

# %% [markdown]
# ### Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_face_generation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "problem_unittests.py" files in your submission.
